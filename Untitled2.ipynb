# %%
import numpy as np
import pandas as pd

# %%
def parse(file_name):
    data = pd.read_csv(file_name)
    X = []
    items = {}
    count = 0
    for i in range(data.shape[0]):
        x = []
        for j in range(data.shape[1]):
            item = data.iloc[i, j]
            if str(item) == "nan":
                continue
            else:
                if item.lower().strip() in items:
                    x.append(items[item.lower().strip()])
                else:
                    items[item.lower().strip()] = count
                    x.append(count)
                    count += 1
        X.append(x)
    return X, items

# %%
X, items = parse("data/a1_market_basket_optimisation.csv")

# %%
def create_candidate_1(X):
    c1 = []
    for transaction in X:
        for i in transaction:
            i = frozenset([i])
            if i not in c1:
                c1.append(i)
    return c1

# %%
def apriori(X, min_support):
    """
    pass in the transaction data and the minimum support 
    threshold to obtain the frequent itemset. Also
    store the support for each itemset, they will
    be used in the rule generation step
    """
    c1 = create_candidate_1(X)
    freq_item, item_support_dict = create_freq_item(X, c1, min_support = 0.01)
    freq_items = [freq_item]
    
    k = 0
    while len(freq_items[k]) > 0:
        freq_item = freq_items[k]
        ck = create_candidate_k(freq_item, k)       
        freq_item, item_support = create_freq_item(X, ck, min_support = 0.01)
        freq_items.append(freq_item)
        item_support_dict.update(item_support)
        k += 1
        
    return freq_items, item_support_dict

# %%
def create_freq_item(X, ck, min_support):
    """
    filters the candidate with the specified
    minimum support
    """
    # loop through the transaction and compute
    # the count for each candidate (item)
    item_count = {}
    for transaction in X:
        for item in ck:
            if item.issubset(transaction):
                if item not in item_count: 
                    item_count[item] = 1
                else: 
                    item_count[item] += 1    
    
    n_row = X.shape[0]
    freq_item = []
    item_support = {}
    
    # if the support of an item is greater than the 
    # min_support, then it is considered as frequent
    for item in item_count:
        support = item_count[item] / n_row
        if support >= min_support:
            freq_item.append(item)
        
        item_support[item] = support
        
    return freq_item, item_support

# %%
def create_candidate_k(freq_item, k):
    """create the list of k-item candidate"""
    ck = []
    
    # for generating candidate of size two (2-itemset)
    if k == 0:
        for f1, f2 in combinations(freq_item, 2):
            item = f1 | f2 # union of two sets
            ck.append(item)
    else:    
        for f1, f2 in combinations(freq_item, 2):       
            # if the two (k+1)-item sets has
            # k common elements then they will be
            # unioned to be the (k+2)-item candidate
            intersection = f1 & f2
            if len(intersection) == k:
                item = f1 | f2
                if item not in ck:
                    ck.append(item)
    return ck

# %%
X = np.array(X)

# %%
freq_items, item_support_dict = apriori(X, min_support = 0.01)

# %%
freq_items
# Out:
# [[frozenset({0}),
#   frozenset({1}),
#   frozenset({2}),
#   frozenset({4}),
#   frozenset({5}),
#   frozenset({6}),
#   frozenset({7}),
#   frozenset({8}),
#   frozenset({9}),
#   frozenset({10}),
#   frozenset({11}),
#   frozenset({12}),
#   frozenset({13}),
#   frozenset({14}),
#   frozenset({15}),
#   frozenset({17}),
#   frozenset({18}),
#   frozenset({20}),
#   frozenset({21}),
#   frozenset({22}),
#   frozenset({23}),
#   frozenset({24}),
#   frozenset({25}),
#   frozenset({26}),
#   frozenset({27}),
#   frozenset({28}),
#   frozenset({29}),
#   frozenset({30}),
#   frozenset({31}),
#   frozenset({32}),
#   frozenset({33}),
#   frozenset({34}),
#   frozenset({35}),
#   frozenset({36}),
#   frozenset({38}),
#   frozenset({40}),
#   frozenset({41}),
#   frozenset({42}),
#   frozenset({43}),
#   frozenset({44}),
#   frozenset({46}),
#   frozenset({47}),
#   frozenset({48}),
#   frozenset({49}),
#   frozenset({50}),
#   frozenset({51}),
#   frozenset({52}),
#   frozenset({53}),
#   frozenset({54}),
#   frozenset({55}),
#   frozenset({58}),
#   frozenset({59}),
#   frozenset({60}),
#   frozenset({61}),
#   frozenset({62}),
#   frozenset({65}),
#   frozenset({66}),
#   frozenset({67}),
#   frozenset({68}),
#   frozenset({70}),
#   frozenset({71}),
#   frozenset({73}),
#   frozenset({74}),
#   frozenset({75}),
#   frozenset({78}),
#   frozenset({80}),
#   frozenset({82}),
#   frozenset({85}),
#   frozenset({87}),
#   frozenset({88}),
#   frozenset({93}),
#   frozenset({95}),
#   frozenset({98}),
#   frozenset({102}),
#   frozenset({109})],
#  [frozenset({0, 2}),
#   frozenset({6, 7}),
#   frozenset({6, 9}),
#   frozenset({6, 10}),
#   frozenset({7, 9}),
#   frozenset({7, 10}),
#   frozenset({10, 17}),
#   frozenset({10, 18}),
#   frozenset({17, 18}),
#   frozenset({0, 4}),
#   frozenset({0, 6}),
#   frozenset({2, 4}),
#   frozenset({2, 6}),
#   frozenset({2, 21}),
#   frozenset({4, 6}),
#   frozenset({6, 21}),
#   frozenset({6, 23}),
#   frozenset({11, 25}),
#   frozenset({21, 25}),
#   frozenset({24, 25}),
#   frozenset({25, 26}),
#   frozenset({2, 18}),
#   frozenset({2, 26}),
#   frozenset({2, 30}),
#   frozenset({4, 18}),
#   frozenset({6, 18}),
#   frozenset({6, 26}),
#   frozenset({6, 30}),
#   frozenset({18, 23}),
#   frozenset({18, 26}),
#   frozenset({18, 30}),
#   frozenset({7, 13}),
#   frozenset({2, 24}),
#   frozenset({2, 25}),
#   frozenset({6, 42}),
#   frozenset({10, 42}),
#   frozenset({18, 42}),
#   frozenset({7, 14}),
#   frozenset({7, 18}),
#   frozenset({14, 18}),
#   frozenset({6, 48}),
#   frozenset({6, 49}),
#   frozenset({6, 50}),
#   frozenset({7, 48}),
#   frozenset({7, 49}),
#   frozenset({18, 48}),
#   frozenset({18, 49}),
#   frozenset({18, 50}),
#   frozenset({2, 13}),
#   frozenset({6, 13}),
#   frozenset({6, 25}),
#   frozenset({13, 25}),
#   frozenset({13, 26}),
#   frozenset({6, 17}),
#   frozenset({5, 6}),
#   frozenset({4, 13}),
#   frozenset({17, 25}),
#   frozenset({6, 34}),
#   frozenset({6, 58}),
#   frozenset({6, 27}),
#   frozenset({9, 18}),
#   frozenset({17, 49}),
#   frozenset({18, 27}),
#   frozenset({10, 13}),
#   frozenset({13, 42}),
#   frozenset({6, 62}),
#   frozenset({0, 10}),
#   frozenset({10, 25}),
#   frozenset({18, 25}),
#   frozenset({13, 50}),
#   frozenset({4, 7}),
#   frozenset({4, 25}),
#   frozenset({6, 14}),
#   frozenset({6, 67}),
#   frozenset({7, 17}),
#   frozenset({7, 25}),
#   frozenset({7, 30}),
#   frozenset({7, 67}),
#   frozenset({14, 25}),
#   frozenset({17, 30}),
#   frozenset({17, 48}),
#   frozenset({17, 67}),
#   frozenset({18, 67}),
#   frozenset({25, 30}),
#   frozenset({25, 48}),
#   frozenset({25, 67}),
#   frozenset({30, 48}),
#   frozenset({48, 67}),
#   frozenset({2, 20}),
#   frozenset({10, 26}),
#   frozenset({4, 10}),
#   frozenset({6, 52}),
#   frozenset({48, 52}),
#   frozenset({6, 11}),
#   frozenset({6, 43}),
#   frozenset({18, 43}),
#   frozenset({43, 48}),
#   frozenset({2, 58}),
#   frozenset({13, 58}),
#   frozenset({0, 7}),
#   frozenset({0, 13}),
#   frozenset({0, 18}),
#   frozenset({13, 18}),
#   frozenset({2, 52}),
#   frozenset({25, 49}),
#   frozenset({11, 13}),
#   frozenset({2, 67}),
#   frozenset({6, 24}),
#   frozenset({18, 24}),
#   frozenset({18, 52}),
#   frozenset({2, 10}),
#   frozenset({10, 20}),
#   frozenset({13, 20}),
#   frozenset({10, 48}),
#   frozenset({0, 25}),
#   frozenset({0, 48}),
#   frozenset({2, 48}),
#   frozenset({2, 7}),
#   frozenset({7, 24}),
#   frozenset({6, 47}),
#   frozenset({22, 25}),
#   frozenset({25, 50}),
#   frozenset({2, 11}),
#   frozenset({2, 42}),
#   frozenset({13, 43}),
#   frozenset({0, 17}),
#   frozenset({0, 42}),
#   frozenset({2, 17}),
#   frozenset({7, 11}),
#   frozenset({7, 42}),
#   frozenset({11, 17}),
#   frozenset({11, 18}),
#   frozenset({13, 17}),
#   frozenset({13, 24}),
#   frozenset({17, 24}),
#   frozenset({17, 42}),
#   frozenset({24, 42}),
#   frozenset({25, 42}),
#   frozenset({18, 58}),
#   frozenset({13, 30}),
#   frozenset({2, 49}),
#   frozenset({7, 21}),
#   frozenset({7, 58}),
#   frozenset({18, 21}),
#   frozenset({18, 34}),
#   frozenset({25, 58}),
#   frozenset({24, 48}),
#   frozenset({9, 25}),
#   frozenset({2, 9}),
#   frozenset({10, 24}),
#   frozenset({42, 67}),
#   frozenset({13, 49}),
#   frozenset({24, 30}),
#   frozenset({42, 48}),
#   frozenset({2, 50}),
#   frozenset({25, 43}),
#   frozenset({0, 58}),
#   frozenset({10, 58}),
#   frozenset({23, 25}),
#   frozenset({10, 49}),
#   frozenset({20, 25}),
#   frozenset({13, 48}),
#   frozenset({9, 13}),
#   frozenset({10, 30}),
#   frozenset({17, 58}),
#   frozenset({42, 58}),
#   frozenset({7, 26})],
#  [frozenset({2, 6, 18}),
#   frozenset({6, 18, 42}),
#   frozenset({6, 7, 18}),
#   frozenset({6, 7, 48}),
#   frozenset({6, 18, 48}),
#   frozenset({2, 6, 25}),
#   frozenset({6, 17, 18}),
#   frozenset({6, 7, 25}),
#   frozenset({6, 7, 17}),
#   frozenset({6, 18, 25}),
#   frozenset({6, 18, 67}),
#   frozenset({7, 18, 25}),
#   frozenset({6, 25, 48}),
#   frozenset({2, 18, 25}),
#   frozenset({2, 6, 48}),
#   frozenset({2, 6, 7}),
#   frozenset({6, 13, 18})],
#  []]

# %%
def create_rules(freq_items, item_support_dict, min_confidence):
    """
    create the association rules, the rules will be a list.
    each element is a tuple of size 4, containing rules'
    left hand side, right hand side, confidence and lift
    """
    association_rules = []

    # for the list that stores the frequent items, loop through
    # the second element to the one before the last to generate the rules
    # because the last one will be an empty list. It's the stopping criteria
    # for the frequent itemset generating process and the first one are all
    # single element frequent itemset, which can't perform the set
    # operation X -> Y - X
    for idx, freq_item in enumerate(freq_items[1:(len(freq_items) - 1)]):
        for freq_set in freq_item:
            
            # start with creating rules for single item on
            # the right hand side
            subsets = [frozenset([item]) for item in freq_set]
            rules, right_hand_side = compute_conf(freq_items, item_support_dict, freq_set, subsets, min_confidence)
            association_rules.extend(rules)
            
            # starting from 3-itemset, loop through each length item
            # to create the rules, as for the while loop condition,
            # e.g. suppose you start with a 3-itemset {2, 3, 5} then the 
            # while loop condition will stop when the right hand side's
            # item is of length 2, e.g. [ {2, 3}, {3, 5} ], since this
            # will be merged into 3 itemset, making the left hand side
            # null when computing the confidence
            if idx != 0:
                k = 0
                while len(right_hand_side[0]) < len(freq_set) - 1:
                    ck = create_candidate_k(right_hand_side, k = k)
                    rules, right_hand_side = compute_conf(freq_items, item_support_dict,
                                                          freq_set, ck, min_confidence)
                    print(right_hand_side)
                    association_rules.extend(rules)
                    k += 1    
    
    return association_rules

# %%
def compute_conf(freq_items, item_support_dict, freq_set, subsets, min_confidence):
    """
    create the rules and returns the rules info and the rules's
    right hand side (used for generating the next round of rules) 
    if it surpasses the minimum confidence threshold
    """
    rules = []
    right_hand_side = []
    
    for rhs in subsets:
        # create the left hand side of the rule
        # and add the rules if it's greater than
        # the confidence threshold
        lhs = freq_set - rhs
        conf = item_support_dict[freq_set] / item_support_dict[lhs]
        if conf >= min_confidence:
            lift = conf / item_support_dict[rhs]
            rules_info = lhs, rhs, conf, lift
            rules.append(rules_info)
            right_hand_side.append(rhs)
            
    return rules, right_hand_side

# %%
association_rules = create_rules(freq_items, item_support_dict, min_confidence = 0.01)
association_rules[-1]
# Out:
# [frozenset({2, 18}), frozenset({2, 6}), frozenset({18, 6})]
# [frozenset({18, 42}), frozenset({18, 6}), frozenset({42, 6})]
# [frozenset({18, 6}), frozenset({18, 7}), frozenset({6, 7})]
# [frozenset({48, 6}), frozenset({48, 7}), frozenset({6, 7})]
# [frozenset({48, 18}), frozenset({48, 6}), frozenset({18, 6})]
# [frozenset({25, 2}), frozenset({25, 6}), frozenset({2, 6})]
# [frozenset({17, 18}), frozenset({17, 6}), frozenset({18, 6})]
# [frozenset({25, 6}), frozenset({25, 7}), frozenset({6, 7})]
# [frozenset({17, 6}), frozenset({17, 7}), frozenset({6, 7})]
# [frozenset({25, 18}), frozenset({25, 6}), frozenset({18, 6})]
# [frozenset({18, 67}), frozenset({18, 6}), frozenset({67, 6})]
# [frozenset({25, 18}), frozenset({25, 7}), frozenset({18, 7})]
# [frozenset({48, 25}), frozenset({48, 6}), frozenset({25, 6})]
# [frozenset({25, 2}), frozenset({25, 18}), frozenset({2, 18})]
# [frozenset({48, 2}), frozenset({48, 6}), frozenset({2, 6})]
# [frozenset({2, 6}), frozenset({2, 7}), frozenset({6, 7})]
# [frozenset({18, 13}), frozenset({18, 6}), frozenset({13, 6})]
# (frozenset({18}), frozenset({6, 13}), 0.05819295558958652, 1.7250876162920907)

# %%
association_rules
# Out:
# [(frozenset({2}), frozenset({0}), 0.16023738872403562, 1.8375847330738029),
#  (frozenset({0}), frozenset({2}), 0.3302752293577982, 1.837584733073803),
#  (frozenset({7}), frozenset({6}), 0.3703703703703704, 1.5544363613753656),
#  (frozenset({6}), frozenset({7}), 0.20145495243424735, 1.5544363613753656),
#  (frozenset({6}), frozenset({9}), 0.08449916060436485, 1.4436075274094224),
#  (frozenset({9}), frozenset({6}), 0.3439635535307517, 1.4436075274094224),
#  (frozenset({6}), frozenset({10}), 0.12982652490207053, 0.9835342795611404),
#  (frozenset({10}), frozenset({6}), 0.23434343434343433, 0.9835342795611401),
#  (frozenset({7}), frozenset({9}), 0.09156378600823045, 1.5643015832841194),
#  (frozenset({9}), frozenset({7}), 0.20273348519362186, 1.5643015832841194),
#  (frozenset({7}), frozenset({10}), 0.1358024691358025, 1.0288065843621401),
#  (frozenset({10}), frozenset({7}), 0.13333333333333333, 1.02880658436214),
#  (frozenset({10}), frozenset({17}), 0.10909090909090909, 1.144310235219326),
#  (frozenset({17}), frozenset({10}), 0.15104895104895102, 1.144310235219326),
#  (frozenset({18}), frozenset({10}), 0.15237366003062786, 1.1543459093229382),
#  (frozenset({10}), frozenset({18}), 0.201010101010101, 1.1543459093229385),
#  (frozenset({18}), frozenset({17}), 0.16003062787136293, 1.6786429496996111),
#  (frozenset({17}), frozenset({18}), 0.2923076923076923, 1.6786429496996114),
#  (frozenset({4}), frozenset({0}), 0.17057569296375266, 1.9561432679329434),
#  (frozenset({0}), frozenset({4}), 0.12232415902140673, 1.9561432679329436),
#  (frozenset({6}), frozenset({0}), 0.10240626748740908, 1.1743838014611132),
#  (frozenset({0}), frozenset({6}), 0.27981651376146793, 1.1743838014611134),
#  (frozenset({4}), frozenset({2}), 0.31130063965884863, 1.7320139446894398),
#  (frozenset({2}), frozenset({4}), 0.1083086053412463, 1.7320139446894398),
#  (frozenset({6}), frozenset({2}), 0.21376608841634023, 1.1893513821383916),
#  (frozenset({2}), frozenset({6}), 0.28338278931750743, 1.1893513821383916),
#  (frozenset({21}), frozenset({2}), 0.22976501305483027, 1.2783661705572902),
#  (frozenset({2}), frozenset({21}), 0.06528189910979229, 1.2783661705572902),
#  (frozenset({6}), frozenset({4}), 0.08058198097369894, 1.288624429216934),
#  (frozenset({4}), frozenset({6}), 0.30703624733475476, 1.288624429216934),
#  (frozenset({6}), frozenset({21}), 0.08449916060436485, 1.6546833016520532),
#  (frozenset({21}), frozenset({6}), 0.3942558746736292, 1.6546833016520532),
#  (frozenset({23}), frozenset({6}), 0.39937106918238996, 1.6761516613698517),
#  (frozenset({6}), frozenset({23}), 0.07106883044208172, 1.676151661369852),
#  (frozenset({11}), frozenset({25}), 0.193717277486911, 1.1821640204652828),
#  (frozenset({25}), frozenset({11}), 0.0903173311635476, 1.1821640204652828),
#  (frozenset({21}), frozenset({25}), 0.2663185378590078, 1.6252148364056618),
#  (frozenset({25}), frozenset({21}), 0.08299430431244914, 1.625214836405662),
#  (frozenset({25}), frozenset({24}), 0.10984540276647681, 1.5398888238291142),
#  (frozenset({24}), frozenset({25}), 0.2523364485981308, 1.539888823829114),
#  (frozenset({26}), frozenset({25}), 0.24444444444444444, 1.4917276918904259),
#  (frozenset({25}), frozenset({26}), 0.08950366151342555, 1.4917276918904259),
#  (frozenset({18}), frozenset({2}), 0.20980091883614088, 1.1672899786877275),
#  (frozenset({2}), frozenset({18}), 0.20326409495548964, 1.1672899786877275),
#  (frozenset({26}), frozenset({2}), 0.24, 1.3353115727002967),
#  (frozenset({2}), frozenset({26}), 0.08011869436201781, 1.3353115727002969),
#  (frozenset({30}), frozenset({2}), 0.1793372319688109, 0.9977961719332952),
#  (frozenset({2}), frozenset({30}), 0.06824925816023739, 0.9977961719332951),
#  (frozenset({4}), frozenset({18}), 0.26439232409381663, 1.5183326421926682),
#  (frozenset({18}), frozenset({4}), 0.09494640122511486, 1.5183326421926684),
#  (frozenset({6}), frozenset({18}), 0.2506994963626189, 1.4396984860027884),
#  (frozenset({18}), frozenset({6}), 0.3430321592649311, 1.4396984860027886),
#  (frozenset({6}), frozenset({26}), 0.09569110240626749, 1.594851706771125),
#  (frozenset({26}), frozenset({6}), 0.38, 1.594851706771125),
#  (frozenset({30}), frozenset({6}), 0.35672514619883045, 1.4971676533246943),
#  (frozenset({6}), frozenset({30}), 0.10240626748740908, 1.497167653324694),
#  (frozenset({23}), frozenset({18}), 0.31761006289308175, 1.8239475280996271),
#  (frozenset({18}), frozenset({23}), 0.0773353751914242, 1.8239475280996271),
#  (frozenset({26}), frozenset({18}), 0.2866666666666667, 1.64624808575804),
#  (frozenset({18}), frozenset({26}), 0.09877488514548238, 1.6462480857580397),
#  (frozenset({30}), frozenset({18}), 0.30604288499025345, 1.757520396192114),
#  (frozenset({18}), frozenset({30}), 0.12021439509954059, 1.7575203961921138),
#  (frozenset({7}), frozenset({13}), 0.1831275720164609, 1.0713391498622908),
#  (frozenset({13}), frozenset({7}), 0.13884555382215288, 1.0713391498622908),
#  (frozenset({2}), frozenset({24}), 0.07863501483679525, 1.102360021076569),
#  (frozenset({24}), frozenset({2}), 0.19813084112149532, 1.102360021076569),
#  (frozenset({2}), frozenset({25}), 0.1847181008902077, 1.127246343919087),
#  (frozenset({25}), frozenset({2}), 0.20260374288039057, 1.127246343919087),
#  (frozenset({6}), frozenset({42}), 0.14157806379406826, 1.489250320414463),
#  (frozenset({42}), frozenset({6}), 0.3548387096774194, 1.489250320414463),
#  (frozenset({42}), frozenset({10}), 0.17251051893408137, 1.3068978707127377),
#  (frozenset({10}), frozenset({42}), 0.12424242424242425, 1.3068978707127377),
#  (frozenset({42}), frozenset({18}), 0.2650771388499299, 1.5222653456159834),
#  (frozenset({18}), frozenset({42}), 0.1447166921898928, 1.5222653456159834),
#  (frozenset({7}), frozenset({14}), 0.11728395061728396, 2.320922505619076),
#  (frozenset({14}), frozenset({7}), 0.3007915567282322, 2.320922505619076),
#  (frozenset({7}), frozenset({18}), 0.27366255144032925, 1.5715690166940808),
#  (frozenset({18}), frozenset({7}), 0.20367534456355282, 1.5715690166940806),
#  (frozenset({14}), frozenset({18}), 0.28232189973614774, 1.6212972802611854),
#  (frozenset({18}), frozenset({14}), 0.08192955589586524, 1.6212972802611856),
#  (frozenset({6}), frozenset({48}), 0.1717963066592054, 1.7482663499919138),
#  (frozenset({48}), frozenset({6}), 0.41655359565807326, 1.7482663499919135),
#  (frozenset({6}), frozenset({49}), 0.08449916060436485, 1.3370120348791905),
#  (frozenset({49}), frozenset({6}), 0.3185654008438818, 1.3370120348791905),
#  (frozenset({6}), frozenset({50}), 0.07162842753217684, 0.9028793386408844),
#  (frozenset({50}), frozenset({6}), 0.21512605042016805, 0.9028793386408844),
#  (frozenset({7}), frozenset({48}), 0.1697530864197531, 1.7274737423991156),
#  (frozenset({48}), frozenset({7}), 0.22388059701492535, 1.7274737423991156),
#  (frozenset({7}), frozenset({49}), 0.11008230452674898, 1.7418086159295723),
#  (frozenset({49}), frozenset({7}), 0.22573839662447256, 1.7418086159295723),
#  (frozenset({18}), frozenset({48}), 0.225114854517611, 2.2908567284695827),
#  (frozenset({48}), frozenset({18}), 0.39891451831750335, 2.2908567284695827),
#  (frozenset({18}), frozenset({49}), 0.0895865237366003, 1.4175082869715234),
#  (frozenset({49}), frozenset({18}), 0.24683544303797464, 1.4175082869715236),
#  (frozenset({50}), frozenset({18}), 0.1764705882352941, 1.0134222142149354),
#  (frozenset({18}), frozenset({50}), 0.08039816232771822, 1.0134222142149356),
#  (frozenset({13}), frozenset({2}), 0.21294851794071765, 1.1848025849817376),
#  (frozenset({2}), frozenset({13}), 0.20252225519287836, 1.1848025849817378),
#  (frozenset({6}), frozenset({13}), 0.14157806379406826, 0.8282648037874508),
#  (frozenset({13}), frozenset({6}), 0.19734789391575663, 0.8282648037874509),
#  (frozenset({6}), frozenset({25}), 0.22104085058757697, 1.3489067367020564),
#  (frozenset({25}), frozenset({6}), 0.32139951179820997, 1.3489067367020564),
#  (frozenset({13}), frozenset({25}), 0.20124804992199688, 1.228120727758321),
#  (frozenset({25}), frozenset({13}), 0.20992676973148902, 1.2281207277583213),
#  (frozenset({13}), frozenset({26}), 0.06474258970358815, 1.0790431617264693),
#  (frozenset({26}), frozenset({13}), 0.18444444444444447, 1.0790431617264693),
#  (frozenset({6}), frozenset({17}), 0.14997202014549524, 1.5731330784492505),
#  (frozenset({17}), frozenset({6}), 0.3748251748251748, 1.5731330784492508),
#  (frozenset({6}), frozenset({5}), 0.04812534974818131, 1.449558727354859),
#  (frozenset({5}), frozenset({6}), 0.3453815261044177, 1.449558727354859),
#  (frozenset({13}), frozenset({4}), 0.062402496099843996, 0.9979077201467591),
#  (frozenset({4}), frozenset({13}), 0.17057569296375266, 0.997907720146759),
#  (frozenset({25}), frozenset({17}), 0.13995117982099267, 1.4680193687516714),
#  (frozenset({17}), frozenset({25}), 0.24055944055944053, 1.4680193687516714),
#  (frozenset({6}), frozenset({34}), 0.04588696138780078, 1.6310531298981321),
#  (frozenset({34}), frozenset({6}), 0.3886255924170616, 1.6310531298981323),
#  (frozenset({6}), frozenset({58}), 0.1152770005595971, 1.422002474008188),
#  (frozenset({58}), frozenset({6}), 0.33881578947368424, 1.422002474008188),
#  (frozenset({6}), frozenset({27}), 0.06267487409065473, 1.3241170582532689),
#  (frozenset({27}), frozenset({6}), 0.3154929577464789, 1.324117058253269),
#  (frozenset({18}), frozenset({9}), 0.08116385911179173, 1.3866262946205876),
#  (frozenset({9}), frozenset({18}), 0.24145785876993164, 1.3866262946205876),
#  (frozenset({49}), frozenset({17}), 0.1582278481012658, 1.6597326723909),
#  (frozenset({17}), frozenset({49}), 0.1048951048951049, 1.6597326723909),
#  (frozenset({27}), frozenset({18}), 0.2507042253521127, 1.4397256432931431),
#  (frozenset({18}), frozenset({27}), 0.0681470137825421, 1.4397256432931431),
#  (frozenset({13}), frozenset({10}), 0.1669266770670827, 1.26459603838699),
#  (frozenset({10}), frozenset({13}), 0.21616161616161617, 1.26459603838699),
#  (frozenset({13}), frozenset({42}), 0.11778471138845555, 1.2389696148855773),
#  (frozenset({42}), frozenset({13}), 0.21178120617110802, 1.2389696148855773),
#  (frozenset({6}), frozenset({62}), 0.04308897593732513, 1.674442070103308),
#  (frozenset({62}), frozenset({6}), 0.3989637305699482, 1.6744420701033083),
#  (frozenset({10}), frozenset({0}), 0.13232323232323231, 1.5174682605875265),
#  (frozenset({0}), frozenset({10}), 0.2003058103975535, 1.5174682605875265),
#  (frozenset({10}), frozenset({25}), 0.17777777777777778, 1.0848928668294007),
#  (frozenset({25}), frozenset({10}), 0.1432058584214809, 1.0848928668294007),
#  (frozenset({18}), frozenset({25}), 0.225114854517611, 1.3737684368446563),
#  (frozenset({25}), frozenset({18}), 0.23921887713588283, 1.3737684368446563),
#  (frozenset({13}), frozenset({50}), 0.09594383775351015, 1.2093761061366823),
#  (frozenset({50}), frozenset({13}), 0.20672268907563027, 1.2093761061366826),
#  (frozenset({7}), frozenset({4}), 0.0874485596707819, 1.3984311247992842),
#  (frozenset({4}), frozenset({7}), 0.18123667377398722, 1.3984311247992842),
#  (frozenset({4}), frozenset({25}), 0.18123667377398722, 1.1060008570422328),
#  (frozenset({25}), frozenset({4}), 0.0691619202603743, 1.1060008570422328),
#  (frozenset({14}), frozenset({6}), 0.45646437994722955, 1.9157710406291113),
#  (frozenset({6}), frozenset({14}), 0.09681029658645775, 1.915771040629111),
#  (frozenset({6}), frozenset({67}), 0.1152770005595971, 1.7537069050648644),
#  (frozenset({67}), frozenset({6}), 0.41784989858012167, 1.7537069050648644),
#  (frozenset({7}), frozenset({17}), 0.18209876543209877, 1.91012691012691),
#  (frozenset({17}), frozenset({7}), 0.24755244755244754, 1.91012691012691),
#  (frozenset({7}), frozenset({25}), 0.24794238683127573, 1.5130739635757267),
#  (frozenset({25}), frozenset({7}), 0.19609438567941417, 1.5130739635757267),
#  (frozenset({7}), frozenset({30}), 0.1080246913580247, 1.5793083531874956),
#  (frozenset({30}), frozenset({7}), 0.2046783625730994, 1.5793083531874954),
#  (frozenset({7}), frozenset({67}), 0.13168724279835392, 2.003355620664613),
#  (frozenset({67}), frozenset({7}), 0.25963488843813387, 2.0033556206646135),
#  (frozenset({14}), frozenset({25}), 0.20052770448548812, 1.223724803613638),
#  (frozenset({25}), frozenset({14}), 0.061838893409275834, 1.223724803613638),
#  (frozenset({30}), frozenset({17}), 0.23586744639376217, 2.4741340530814213),
#  (frozenset({17}), frozenset({30}), 0.1692307692307692, 2.4741340530814213),
#  (frozenset({17}), frozenset({48}), 0.17762237762237762, 1.8075547247867465),
#  (frozenset({48}), frozenset({17}), 0.17232021709633652, 1.8075547247867465),
#  (frozenset({67}), frozenset({17}), 0.1724137931034483, 1.808536291294912),
#  (frozenset({17}), frozenset({67}), 0.11888111888111888, 1.808536291294912),
#  (frozenset({67}), frozenset({18}), 0.3488843813387424, 2.0035473660341254),
#  (frozenset({18}), frozenset({67}), 0.13169984686064318, 2.0035473660341254),
#  (frozenset({30}), frozenset({25}), 0.2046783625730994, 1.24905428746806),
#  (frozenset({25}), frozenset({30}), 0.0854353132628153, 1.24905428746806),
#  (frozenset({25}), frozenset({48}), 0.14076484947111473, 1.432478115377694),
#  (frozenset({48}), frozenset({25}), 0.23473541383989144, 1.432478115377694),
#  (frozenset({67}), frozenset({25}), 0.24949290060851928, 1.5225360085955204),
#  (frozenset({25}), frozenset({67}), 0.10008136696501221, 1.5225360085955204),
#  (frozenset({30}), frozenset({48}), 0.17153996101364521, 1.7456576765296323),
#  (frozenset({48}), frozenset({30}), 0.11940298507462686, 1.7456576765296326),
#  (frozenset({67}), frozenset({48}), 0.21501014198782958, 2.1880272251135984),
#  (frozenset({48}), frozenset({67}), 0.14382632293080053, 2.188027225113598),
#  (frozenset({20}), frozenset({2}), 0.13101160862354894, 0.7289221548046121),
#  (frozenset({2}), frozenset({20}), 0.058605341246290805, 0.728922154804612),
#  (frozenset({26}), frozenset({10}), 0.19777777777777777, 1.4983164983164983),
#  (frozenset({10}), frozenset({26}), 0.0898989898989899, 1.4983164983164983),
#  (frozenset({4}), frozenset({10}), 0.18976545842217485, 1.4376171092589003),
#  (frozenset({10}), frozenset({4}), 0.0898989898989899, 1.4376171092589003),
#  (frozenset({6}), frozenset({52}), 0.07162842753217684, 1.4480140336693432),
#  (frozenset({52}), frozenset({6}), 0.3450134770889488, 1.4480140336693432),
#  (frozenset({52}), frozenset({48}), 0.3234501347708895, 3.2915549671393096),
#  (frozenset({48}), frozenset({52}), 0.1628222523744912, 3.2915549671393096),
#  (frozenset({6}), frozenset({11}), 0.10016787912702856, 1.3110978943328346),
#  (frozenset({11}), frozenset({6}), 0.31239092495637, 1.3110978943328344),
#  (frozenset({6}), frozenset({43}), 0.07330721880246223, 1.3989927252378287),
#  (frozenset({43}), frozenset({6}), 0.3333333333333333, 1.3989927252378287),
#  (frozenset({43}), frozenset({18}), 0.3155216284987277, 1.8119542218533369),
#  (frozenset({18}), frozenset({43}), 0.09494640122511486, 1.8119542218533369),
#  (frozenset({43}), frozenset({48}), 0.2162849872773537, 2.201000548955431),
#  (frozenset({48}), frozenset({43}), 0.11533242876526459, 2.201000548955431),
#  (frozenset({58}), frozenset({2}), 0.23519736842105263, 1.3085906996720287),
#  (frozenset({2}), frozenset({58}), 0.10608308605341246, 1.308590699672029),
#  (frozenset({13}), frozenset({58}), 0.10452418096723869, 1.2893607849577142),
#  (frozenset({58}), frozenset({13}), 0.22039473684210528, 1.2893607849577142),
#  (frozenset({7}), frozenset({0}), 0.13786008230452676, 1.5809642466115454),
#  (frozenset({0}), frozenset({7}), 0.20489296636085627, 1.5809642466115454),
#  (frozenset({13}), frozenset({0}), 0.12870514820592824, 1.4759764702514706),
#  (frozenset({0}), frozenset({13}), 0.25229357798165136, 1.4759764702514706),
#  (frozenset({18}), frozenset({0}), 0.1232771822358346, 1.413729154080672),
#  (frozenset({0}), frozenset({18}), 0.24617737003058102, 1.413729154080672),
#  (frozenset({13}), frozenset({18}), 0.16146645865834633, 0.9272576109782522),
#  (frozenset({18}), frozenset({13}), 0.1584992343032159, 0.9272576109782522),
#  (frozenset({52}), frozenset({2}), 0.2533692722371968, 1.4096955057707536),
#  (frozenset({2}), frozenset({52}), 0.06973293768545995, 1.4096955057707536),
#  (frozenset({49}), frozenset({25}), 0.2362869198312236, 1.4419462154061653),
#  (frozenset({25}), frozenset({49}), 0.09113100081366965, 1.4419462154061653),
#  (frozenset({13}), frozenset({11}), 0.078003120124805, 1.0209832477068717),
#  (frozenset({11}), frozenset({13}), 0.17452006980802795, 1.0209832477068719),
#  (frozenset({67}), frozenset({2}), 0.18255578093306288, 1.015703528930246),
#  (frozenset({2}), frozenset({67}), 0.06676557863501484, 1.0157035289302458),
#  (frozenset({6}), frozenset({24}), 0.09848908785674315, 1.3806881475244368),
#  (frozenset({24}), frozenset({6}), 0.32897196261682243, 1.3806881475244368),
#  (frozenset({18}), frozenset({24}), 0.1217457886676876, 1.706716663565714),
#  (frozenset({24}), frozenset({18}), 0.297196261682243, 1.706716663565714),
#  (frozenset({52}), frozenset({18}), 0.32884097035040427, 1.8884435510168698),
#  (frozenset({18}), frozenset({52}), 0.09341500765696784, 1.88844355101687),
#  (frozenset({10}), frozenset({2}), 0.19292929292929292, 1.07341965650571),
#  (frozenset({2}), frozenset({10}), 0.14169139465875372, 1.07341965650571),
#  (frozenset({20}), frozenset({10}), 0.1492537313432836, 1.1307100859339665),
#  (frozenset({10}), frozenset({20}), 0.09090909090909091, 1.1307100859339665),
#  (frozenset({13}), frozenset({20}), 0.078003120124805, 0.9701880612537935),
#  (frozenset({20}), frozenset({13}), 0.1658374792703151, 0.9701880612537936),
#  (frozenset({10}), frozenset({48}), 0.11212121212121212, 1.1409892685333662),
#  (frozenset({48}), frozenset({10}), 0.15061058344640435, 1.1409892685333662),
#  (frozenset({25}), frozenset({0}), 0.10414971521562247, 1.194377468069065),
#  (frozenset({0}), frozenset({25}), 0.19571865443425077, 1.1943774680690649),
#  (frozenset({48}), frozenset({0}), 0.12211668928086838, 1.4004207486338118),
#  (frozenset({0}), frozenset({48}), 0.13761467889908258, 1.4004207486338118),
#  (frozenset({2}), frozenset({48}), 0.1112759643916914, 1.1323876973374294),
#  (frozenset({48}), frozenset({2}), 0.20352781546811397, 1.1323876973374294),
#  (frozenset({7}), frozenset({2}), 0.23765432098765435, 1.3222606879876913),
#  (frozenset({2}), frozenset({7}), 0.17136498516320475, 1.322260687987691),
#  (frozenset({7}), frozenset({24}), 0.1358024691358025, 1.9037729318103154),
#  (frozenset({24}), frozenset({7}), 0.24672897196261684, 1.9037729318103151),
#  (frozenset({47}), frozenset({6}), 0.30959752321981426, 1.2993740482085099),
#  (frozenset({6}), frozenset({47}), 0.05595970900951316, 1.2993740482085097),
#  (frozenset({22}), frozenset({25}), 0.24786324786324784, 1.5125910162525296),
#  (frozenset({25}), frozenset({22}), 0.07078925956061839, 1.5125910162525298),
#  (frozenset({50}), frozenset({25}), 0.2218487394957983, 1.353836896841731),
#  (frozenset({25}), frozenset({50}), 0.10740439381611067, 1.353836896841731),
#  (frozenset({11}), frozenset({2}), 0.2198952879581152, 1.2234530116363975),
#  (frozenset({2}), frozenset({11}), 0.09347181008902077, 1.2234530116363975),
#  (frozenset({42}), frozenset({2}), 0.2286115007012623, 1.2719482605782397),
#  (frozenset({2}), frozenset({42}), 0.120919881305638, 1.27194826057824),
#  (frozenset({13}), frozenset({43}), 0.060842433697347896, 1.1611151468959522),
#  (frozenset({43}), frozenset({13}), 0.19847328244274806, 1.161115146895952),
#  (frozenset({17}), frozenset({0}), 0.11048951048951049, 1.2670815423109),
#  (frozenset({0}), frozenset({17}), 0.12079510703363915, 1.2670815423109),
#  (frozenset({42}), frozenset({0}), 0.11079943899018234, 1.270635768236036),
#  (frozenset({0}), frozenset({42}), 0.12079510703363915, 1.270635768236036),
#  (frozenset({2}), frozenset({17}), 0.120919881305638, 1.268390363345853),
#  (frozenset({17}), frozenset({2}), 0.22797202797202795, 1.2683903633458529),
#  (frozenset({7}), frozenset({11}), 0.10185185185185186, 1.333139422144658),
#  (frozenset({11}), frozenset({7}), 0.17277486910994766, 1.333139422144658),
#  (frozenset({7}), frozenset({42}), 0.12757201646090535, 1.3419216317767044),
#  (frozenset({42}), frozenset({7}), 0.1739130434782609, 1.3419216317767044),
#  (frozenset({11}), frozenset({17}), 0.13263525305410123, 1.391278878189873),
#  (frozenset({17}), frozenset({11}), 0.10629370629370628, 1.3912788781898728),
#  (frozenset({11}), frozenset({18}), 0.19895287958115185, 1.1425318505808872),
#  (frozenset({18}), frozenset({11}), 0.08728943338437979, 1.1425318505808875),
#  (frozenset({13}), frozenset({17}), 0.11154446177847113, 1.1700468018720747),
#  (frozenset({17}), frozenset({13}), 0.19999999999999998, 1.1700468018720749),
#  (frozenset({13}), frozenset({24}), 0.05850234009360375, 0.8201262629944451),
#  (frozenset({24}), frozenset({13}), 0.14018691588785048, 0.8201262629944451),
#  (frozenset({17}), frozenset({24}), 0.17482517482517482, 2.4508202078295533),
#  (frozenset({24}), frozenset({17}), 0.2336448598130841, 2.4508202078295533),
#  (frozenset({42}), frozenset({17}), 0.14165497896213183, 1.4858913877146696),
#  (frozenset({17}), frozenset({42}), 0.14125874125874124, 1.4858913877146696),
#  (frozenset({42}), frozenset({24}), 0.11079943899018234, 1.5532631634137712),
#  (frozenset({24}), frozenset({42}), 0.14766355140186918, 1.5532631634137712),
#  (frozenset({42}), frozenset({25}), 0.20897615708274897, 1.2752816746302826),
#  (frozenset({25}), frozenset({42}), 0.12123677786818553, 1.2752816746302826),
#  (frozenset({58}), frozenset({18}), 0.22368421052631582, 1.2845571048601598),
#  (frozenset({18}), frozenset({58}), 0.10413476263399694, 1.2845571048601598),
#  (frozenset({30}), frozenset({13}), 0.17543859649122806, 1.0263568437474342),
#  (frozenset({13}), frozenset({30}), 0.0702028081123245, 1.0263568437474342),
#  (frozenset({2}), frozenset({49}), 0.06157270029673591, 0.9742515869736693),
#  (frozenset({49}), frozenset({2}), 0.1751054852320675, 0.9742515869736694),
#  (frozenset({7}), frozenset({21}), 0.08847736625514403, 1.7325855010798439),
#  (frozenset({21}), frozenset({7}), 0.22454308093994776, 1.7325855010798439),
#  (frozenset({7}), frozenset({58}), 0.10288065843621401, 1.2690870695256664),
#  (frozenset({58}), frozenset({7}), 0.16447368421052633, 1.2690870695256662),
#  (frozenset({21}), frozenset({18}), 0.31070496083550914, 1.784293419805757),
#  (frozenset({18}), frozenset({21}), 0.09111791730474733, 1.784293419805757),
#  (frozenset({34}), frozenset({18}), 0.36492890995260663, 2.0956866957462097),
#  (frozenset({18}), frozenset({34}), 0.058958652373660034, 2.0956866957462097),
#  (frozenset({58}), frozenset({25}), 0.16776315789473684, 1.0237784249068562),
#  (frozenset({25}), frozenset({58}), 0.08299430431244914, 1.0237784249068562),
#  (frozenset({48}), frozenset({24}), 0.11668928086838534, 1.6358310402110094),
#  (frozenset({24}), frozenset({48}), 0.16074766355140188, 1.6358310402110097),
#  (frozenset({25}), frozenset({9}), 0.07323026851098455, 1.2510865918733123),
#  (frozenset({9}), frozenset({25}), 0.2050113895216401, 1.2510865918733123),
#  (frozenset({2}), frozenset({9}), 0.06083086053412463, 1.0392516036581656),
#  (frozenset({9}), frozenset({2}), 0.1867881548974943, 1.0392516036581658),
#  (frozenset({10}), frozenset({24}), 0.08585858585858586, 1.2036250354007363),
#  (frozenset({24}), frozenset({10}), 0.15887850467289721, 1.2036250354007365),
#  (frozenset({67}), frozenset({42}), 0.16430020283975658, 1.728263003223246),
#  (frozenset({42}), frozenset({67}), 0.11360448807854139, 1.728263003223246),
#  (frozenset({13}), frozenset({49}), 0.08502340093603745, 1.3453069768360355),
#  (frozenset({49}), frozenset({13}), 0.229957805907173, 1.3453069768360355),
#  (frozenset({30}), frozenset({24}), 0.16374269005847952, 2.295458271847844),
#  (frozenset({24}), frozenset({30}), 0.15700934579439252, 2.295458271847844),
#  (frozenset({42}), frozenset({48}), 0.15287517531556805, 1.5557175235641252),
#  (frozenset({48}), frozenset({42}), 0.14789687924016282, 1.5557175235641252),
#  (frozenset({50}), frozenset({2}), 0.13949579831932774, 0.7761264743286039),
#  (frozenset({2}), frozenset({50}), 0.06157270029673591, 0.7761264743286038),
#  (frozenset({43}), frozenset({25}), 0.20865139949109412, 1.2732998341604604),
#  (frozenset({25}), frozenset({43}), 0.06672091131000814, 1.2732998341604607),
#  (frozenset({58}), frozenset({0}), 0.14144736842105263, 1.6221028488652824),
#  (frozenset({0}), frozenset({58}), 0.13149847094801223, 1.6221028488652824),
#  (frozenset({58}), frozenset({10}), 0.1743421052631579, 1.3207735247208932),
#  (frozenset({10}), frozenset({58}), 0.10707070707070707, 1.3207735247208932),
#  (frozenset({23}), frozenset({25}), 0.25157232704402516, 1.535225754947265),
#  (frozenset({25}), frozenset({23}), 0.06509357200976404, 1.535225754947265),
#  (frozenset({10}), frozenset({49}), 0.08383838383838384, 1.3265567063035415),
#  (frozenset({49}), frozenset({10}), 0.1751054852320675, 1.3265567063035417),
#  (frozenset({20}), frozenset({25}), 0.12935323383084577, 0.7893810038497504),
#  (frozenset({25}), frozenset({20}), 0.06346623270951994, 0.7893810038497505),
#  (frozenset({13}), frozenset({48}), 0.0811232449297972, 0.8255418412123188),
#  (frozenset({48}), frozenset({13}), 0.14111261872455902, 0.8255418412123188),
#  (frozenset({13}), frozenset({9}), 0.06162246489859595, 1.0527755962174707),
#  (frozenset({9}), frozenset({13}), 0.17995444191343965, 1.0527755962174707),
#  (frozenset({30}), frozenset({10}), 0.1793372319688109, 1.358615393703113),
#  (frozenset({10}), frozenset({30}), 0.09292929292929293, 1.358615393703113),
#  (frozenset({58}), frozenset({17}), 0.12664473684210528, 1.3284412955465588),
#  (frozenset({17}), frozenset({58}), 0.10769230769230768, 1.3284412955465588),
#  (frozenset({58}), frozenset({42}), 0.14638157894736842, 1.539778179670776),
#  (frozenset({42}), frozenset({58}), 0.12482468443197756, 1.539778179670776),
#  (frozenset({7}), frozenset({26}), 0.11419753086419754, 1.903292181069959),
#  (frozenset({26}), frozenset({7}), 0.24666666666666667, 1.903292181069959),
#  (frozenset({6, 18}), frozenset({2}), 0.23883928571428573, 1.3288535926239933),
#  (frozenset({2, 6}), frozenset({18}), 0.28010471204188486, 1.608564579107302),
#  (frozenset({2, 18}), frozenset({6}), 0.3905109489051095, 1.638965929931909),
#  (frozenset({6}), frozenset({2, 18}), 0.05987688864017907, 1.6389659299319088),
#  (frozenset({18}), frozenset({2, 6}), 0.08192955589586524, 1.608564579107302),
#  (frozenset({2}), frozenset({6, 18}), 0.07937685459940653, 1.3288535926239933),
#  (frozenset({6, 42}), frozenset({18}), 0.3399209486166008, 1.9520728289621028),
#  (frozenset({6, 18}),
#   frozenset({42}),
#   0.19196428571428573,
#   2.0192596674013226),
#  (frozenset({18, 42}), frozenset({6}), 0.455026455026455, 1.9097361011183058),
#  (frozenset({6}), frozenset({18, 42}), 0.04812534974818131, 1.909736101118306),
#  (frozenset({42}), frozenset({6, 18}), 0.120617110799439, 2.0192596674013226),
#  (frozenset({18}),
#   frozenset({6, 42}),
#   0.06584992343032159,
#   1.9520728289621025),
#  (frozenset({6, 7}), frozenset({18}), 0.3277777777777777, 1.8823379275140375),
#  (frozenset({7, 18}), frozenset({6}), 0.44360902255639095, 1.8618173862187646),
#  (frozenset({6, 18}), frozenset({7}), 0.2633928571428571, 2.0323522927689592),
#  (frozenset({7}), frozenset({6, 18}), 0.1213991769547325, 2.0323522927689592),
#  (frozenset({6}), frozenset({7, 18}), 0.06603245663122552, 1.8618173862187646),
#  (frozenset({18}), frozenset({6, 7}), 0.0903522205206738, 1.8823379275140375),
#  (frozenset({6, 7}), frozenset({48}), 0.23055555555555557, 2.346223428312981),
#  (frozenset({7, 48}), frozenset({6}), 0.503030303030303, 2.1112072035407237),
#  (frozenset({6, 48}), frozenset({7}), 0.2703583061889251, 2.086098041581212),
#  (frozenset({7}), frozenset({6, 48}), 0.08539094650205763, 2.0860980415812125),
#  (frozenset({6}), frozenset({7, 48}), 0.04644655847789592, 2.111207203540724),
#  (frozenset({48}), frozenset({6, 7}), 0.11261872455902307, 2.3462234283129804),
#  (frozenset({6, 18}), frozenset({48}), 0.28571428571428575, 2.907540220973057),
#  (frozenset({6, 48}), frozenset({18}), 0.4169381107491857, 2.3943612791875135),
#  (frozenset({18, 48}), frozenset({6}), 0.435374149659864, 1.8272558043922664),
#  (frozenset({6}),
#   frozenset({18, 48}),
#   0.07162842753217684,
#   1.8272558043922664),
#  (frozenset({18}),
#   frozenset({6, 48}),
#   0.09800918836140889,
#   2.3943612791875135),
#  (frozenset({48}), frozenset({6, 18}), 0.17367706919945727, 2.907540220973057),
#  (frozenset({2, 6}), frozenset({25}), 0.26439790575916233, 1.6134941360404538),
#  (frozenset({6, 25}), frozenset({2}), 0.25569620253164554, 1.422642076400105),
#  (frozenset({2, 25}), frozenset({6}), 0.40562248995983935, 1.7023887379400084),
#  (frozenset({6}),
#   frozenset({2, 25}),
#   0.056519306099608285,
#   1.7023887379400087),
#  (frozenset({2}), frozenset({6, 25}), 0.07492581602373888, 1.4226420764001053),
#  (frozenset({25}), frozenset({2, 6}), 0.0821806346623271, 1.6134941360404536),
#  (frozenset({6, 18}), frozenset({17}), 0.20089285714285715, 2.107267732267732),
#  (frozenset({6, 17}), frozenset({18}), 0.3358208955223881, 1.9285273479463327),
#  (frozenset({17, 18}),
#   frozenset({6}),
#   0.43062200956937796,
#   1.8073111761445635),
#  (frozenset({6}),
#   frozenset({17, 18}),
#   0.05036373810856184,
#   1.8073111761445635),
#  (frozenset({18}),
#   frozenset({6, 17}),
#   0.06891271056661562,
#   1.9285273479463327),
#  (frozenset({17}), frozenset({6, 18}), 0.12587412587412586, 2.107267732267732),
#  (frozenset({6, 7}), frozenset({25}), 0.2916666666666667, 1.7799023596419856),
#  (frozenset({7, 25}), frozenset({6}), 0.43568464730290457, 1.8285589562237181),
#  (frozenset({6, 25}), frozenset({7}), 0.2658227848101266, 2.0511017346460387),
#  (frozenset({7}), frozenset({6, 25}), 0.1080246913580247, 2.0511017346460387),
#  (frozenset({6}), frozenset({7, 25}), 0.05875769445998881, 1.8285589562237181),
#  (frozenset({25}), frozenset({6, 7}), 0.0854353132628153, 1.7799023596419854),
#  (frozenset({6, 7}), frozenset({17}), 0.23055555555555557, 2.4184149184149186),
#  (frozenset({7, 17}), frozenset({6}), 0.46892655367231645, 1.968074511775251),
#  (frozenset({6, 17}), frozenset({7}), 0.30970149253731344, 2.3896720103187765),
#  (frozenset({7}), frozenset({6, 17}), 0.08539094650205763, 2.389672010318777),
#  (frozenset({6}), frozenset({7, 17}), 0.04644655847789592, 1.968074511775251),
#  (frozenset({17}), frozenset({6, 7}), 0.11608391608391608, 2.418414918414918),
#  (frozenset({6, 18}), frozenset({25}), 0.265625, 1.6209825061025225),
#  (frozenset({6, 25}), frozenset({18}), 0.3012658227848101, 1.730087037431911),
#  (frozenset({18, 25}), frozenset({6}), 0.4047619047619048, 1.6987768806459353),
#  (frozenset({6}),
#   frozenset({18, 25}),
#   0.06659205372132065,
#   1.6987768806459351),
#  (frozenset({18}),
#   frozenset({6, 25}),
#   0.09111791730474733,
#   1.7300870374319113),
#  (frozenset({25}),
#   frozenset({6, 18}),
#   0.09682668836452402,
#   1.6209825061025227),
#  (frozenset({6, 67}), frozenset({18}), 0.3737864077669903, 2.1465528776817973),
#  (frozenset({6, 18}), frozenset({67}), 0.171875, 2.614731237322515),
#  (frozenset({18, 67}), frozenset({6}), 0.4476744186046512, 1.8788797647089446),
#  (frozenset({6}),
#   frozenset({18, 67}),
#   0.04308897593732513,
#   1.8788797647089446),
#  (frozenset({67}), frozenset({6, 18}), 0.1561866125760649, 2.614731237322515),
#  (frozenset({18}),
#   frozenset({6, 67}),
#   0.058958652373660034,
#   2.1465528776817973),
#  (frozenset({7, 18}), frozenset({25}), 0.3082706766917293, 1.8812287023498535),
#  (frozenset({7, 25}),
#   frozenset({18}),
#   0.34024896265560167,
#   1.9539565236730572),
#  (frozenset({18, 25}), frozenset({7}), 0.2789115646258503, 2.15209540606366),
#  (frozenset({7}), frozenset({18, 25}), 0.08436213991769548, 2.15209540606366),
#  (frozenset({18}), frozenset({7, 25}), 0.06278713629402756, 1.953956523673057),
#  (frozenset({25}),
#   frozenset({7, 18}),
#   0.06672091131000814,
#   1.8812287023498535),
#  (frozenset({6, 25}),
#   frozenset({48}),
#   0.20759493670886076,
#   2.1125671985297907),
#  (frozenset({6, 48}), frozenset({25}), 0.2671009771986971, 1.6299896899839121),
#  (frozenset({25, 48}),
#   frozenset({6}),
#   0.47398843930635837,
#   1.9893191353092825),
#  (frozenset({6}),
#   frozenset({25, 48}),
#   0.04588696138780078,
#   1.9893191353092825),
#  (frozenset({25}),
#   frozenset({6, 48}),
#   0.06672091131000814,
#   1.6299896899839121),
#  (frozenset({48}), frozenset({6, 25}), 0.1112618724559023, 2.1125671985297907),
#  (frozenset({2, 18}),
#   frozenset({25}),
#   0.28832116788321166,
#   1.7594863784573536),
#  (frozenset({18, 25}), frozenset({2}), 0.2687074829931973, 1.4950342154666023),
#  (frozenset({2, 25}), frozenset({18}), 0.3172690763052209, 1.8219893355965977),
#  (frozenset({18}), frozenset({2, 25}), 0.06049004594180705, 1.821989335596598),
#  (frozenset({2}),
#   frozenset({18, 25}),
#   0.058605341246290805,
#   1.4950342154666023),
#  (frozenset({25}), frozenset({2, 18}), 0.064279902359642, 1.7594863784573538),
#  (frozenset({2, 6}), frozenset({48}), 0.19895287958115182, 2.0246222481121285),
#  (frozenset({6, 48}), frozenset({2}), 0.24755700325732896, 1.3773572139688184),
#  (frozenset({2, 48}), frozenset({6}), 0.5066666666666666, 2.1264689423614995),
#  (frozenset({6}),
#   frozenset({2, 48}),
#   0.042529378847229994,
#   2.1264689423614995),
#  (frozenset({2}), frozenset({6, 48}), 0.05637982195845697, 1.3773572139688184),
#  (frozenset({48}), frozenset({2, 6}), 0.10312075983717774, 2.0246222481121285),
#  (frozenset({6, 7}), frozenset({2}), 0.27222222222222225, 1.5145895153313553),
#  (frozenset({2, 7}), frozenset({6}), 0.42424242424242425, 1.7805361957572368),
#  (frozenset({2, 6}), frozenset({7}), 0.2565445026178011, 1.9795100510632802),
#  (frozenset({7}), frozenset({2, 6}), 0.10082304526748972, 1.9795100510632802),
#  (frozenset({6}), frozenset({2, 7}), 0.054840514829322895, 1.7805361957572368),
#  (frozenset({2}), frozenset({6, 7}), 0.07270029673590506, 1.5145895153313553),
#  (frozenset({6, 13}),
#   frozenset({18}),
#   0.30039525691699603,
#   1.7250876162920905),
#  (frozenset({6, 18}),
#   frozenset({13}),
#   0.16964285714285712,
#   0.9924504123022063),
#  (frozenset({13, 18}), frozenset({6}), 0.36714975845410625, 1.540919523450362),
#  (frozenset({6}),
#   frozenset({13, 18}),
#   0.042529378847229994,
#   1.540919523450362),
#  (frozenset({13}),
#   frozenset({6, 18}),
#   0.059282371294851796,
#   0.9924504123022064),
#  (frozenset({18}),
#   frozenset({6, 13}),
#   0.05819295558958652,
#   1.7250876162920907)]

# %%
for x in item_support_dict:
    print(x)
# Out:
# frozenset({0})
# frozenset({1})
# frozenset({2})
# frozenset({3})
# frozenset({4})
# frozenset({5})
# frozenset({6})
# frozenset({7})
# frozenset({8})
# frozenset({9})
# frozenset({10})
# frozenset({11})
# frozenset({12})
# frozenset({13})
# frozenset({14})
# frozenset({15})
# frozenset({16})
# frozenset({17})
# frozenset({18})
# frozenset({19})
# frozenset({20})
# frozenset({21})
# frozenset({22})
# frozenset({23})
# frozenset({24})
# frozenset({25})
# frozenset({26})
# frozenset({27})
# frozenset({28})
# frozenset({29})
# frozenset({30})
# frozenset({31})
# frozenset({32})
# frozenset({33})
# frozenset({34})
# frozenset({35})
# frozenset({36})
# frozenset({37})
# frozenset({38})
# frozenset({39})
# frozenset({40})
# frozenset({41})
# frozenset({42})
# frozenset({43})
# frozenset({44})
# frozenset({45})
# frozenset({46})
# frozenset({47})
# frozenset({48})
# frozenset({49})
# frozenset({50})
# frozenset({51})
# frozenset({52})
# frozenset({53})
# frozenset({54})
# frozenset({55})
# frozenset({56})
# frozenset({57})
# frozenset({58})
# frozenset({59})
# frozenset({60})
# frozenset({61})
# frozenset({62})
# frozenset({63})
# frozenset({64})
# frozenset({65})
# frozenset({66})
# frozenset({67})
# frozenset({68})
# frozenset({69})
# frozenset({70})
# frozenset({71})
# frozenset({72})
# frozenset({73})
# frozenset({74})
# frozenset({75})
# frozenset({76})
# frozenset({77})
# frozenset({78})
# frozenset({79})
# frozenset({80})
# frozenset({81})
# frozenset({82})
# frozenset({83})
# frozenset({84})
# frozenset({85})
# frozenset({86})
# frozenset({87})
# frozenset({88})
# frozenset({89})
# frozenset({90})
# frozenset({91})
# frozenset({92})
# frozenset({93})
# frozenset({94})
# frozenset({95})
# frozenset({96})
# frozenset({97})
# frozenset({98})
# frozenset({99})
# frozenset({100})
# frozenset({101})
# frozenset({102})
# frozenset({103})
# frozenset({104})
# frozenset({105})
# frozenset({106})
# frozenset({107})
# frozenset({108})
# frozenset({109})
# frozenset({110})
# frozenset({111})
# frozenset({112})
# frozenset({113})
# frozenset({114})
# frozenset({115})
# frozenset({116})
# frozenset({117})
# frozenset({118})
# frozenset({0, 1})
# frozenset({0, 2})
# frozenset({1, 2})
# frozenset({4, 5})
# frozenset({6, 7})
# frozenset({8, 6})
# frozenset({9, 6})
# frozenset({10, 6})
# frozenset({8, 7})
# frozenset({9, 7})
# frozenset({10, 7})
# frozenset({8, 9})
# frozenset({8, 10})
# frozenset({9, 10})
# frozenset({12, 13})
# frozenset({14, 15})
# frozenset({17, 10})
# frozenset({10, 18})
# frozenset({17, 18})
# frozenset({0, 4})
# frozenset({0, 6})
# frozenset({0, 21})
# frozenset({2, 4})
# frozenset({2, 6})
# frozenset({2, 21})
# frozenset({4, 6})
# frozenset({4, 21})
# frozenset({21, 6})
# frozenset({18, 20})
# frozenset({18, 22})
# frozenset({20, 22})
# frozenset({6, 23})
# frozenset({11, 21})
# frozenset({24, 11})
# frozenset({25, 11})
# frozenset({26, 11})
# frozenset({27, 11})
# frozenset({11, 28})
# frozenset({24, 21})
# frozenset({25, 21})
# frozenset({26, 21})
# frozenset({27, 21})
# frozenset({28, 21})
# frozenset({24, 25})
# frozenset({24, 26})
# frozenset({24, 27})
# frozenset({24, 28})
# frozenset({25, 26})
# frozenset({25, 27})
# frozenset({25, 28})
# frozenset({26, 27})
# frozenset({26, 28})
# frozenset({27, 28})
# frozenset({2, 18})
# frozenset({2, 23})
# frozenset({2, 26})
# frozenset({2, 29})
# frozenset({2, 30})
# frozenset({2, 31})
# frozenset({32, 2})
# frozenset({18, 4})
# frozenset({4, 23})
# frozenset({26, 4})
# frozenset({4, 29})
# frozenset({4, 30})
# frozenset({4, 31})
# frozenset({32, 4})
# frozenset({18, 6})
# frozenset({26, 6})
# frozenset({29, 6})
# frozenset({6, 30})
# frozenset({6, 31})
# frozenset({32, 6})
# frozenset({18, 23})
# frozenset({18, 26})
# frozenset({18, 29})
# frozenset({18, 30})
# frozenset({18, 31})
# frozenset({32, 18})
# frozenset({26, 23})
# frozenset({29, 23})
# frozenset({30, 23})
# frozenset({31, 23})
# frozenset({32, 23})
# frozenset({26, 29})
# frozenset({26, 30})
# frozenset({26, 31})
# frozenset({32, 26})
# frozenset({29, 30})
# frozenset({29, 31})
# frozenset({32, 29})
# frozenset({30, 31})
# frozenset({32, 30})
# frozenset({32, 31})
# frozenset({1, 7})
# frozenset({1, 13})
# frozenset({1, 27})
# frozenset({1, 33})
# frozenset({13, 7})
# frozenset({27, 7})
# frozenset({33, 7})
# frozenset({27, 13})
# frozenset({33, 13})
# frozenset({33, 27})
# frozenset({24, 2})
# frozenset({25, 2})
# frozenset({2, 34})
# frozenset({2, 35})
# frozenset({2, 36})
# frozenset({24, 34})
# frozenset({24, 35})
# frozenset({24, 36})
# frozenset({25, 34})
# frozenset({25, 35})
# frozenset({25, 36})
# frozenset({34, 35})
# frozenset({34, 36})
# frozenset({35, 36})
# frozenset({40, 6})
# frozenset({41, 6})
# frozenset({42, 6})
# frozenset({40, 10})
# frozenset({41, 10})
# frozenset({10, 42})
# frozenset({40, 18})
# frozenset({41, 18})
# frozenset({18, 42})
# frozenset({40, 41})
# frozenset({40, 42})
# frozenset({41, 42})
# frozenset({0, 5})
# frozenset({0, 24})
# frozenset({0, 27})
# frozenset({0, 35})
# frozenset({0, 43})
# frozenset({0, 44})
# frozenset({24, 5})
# frozenset({27, 5})
# frozenset({35, 5})
# frozenset({43, 5})
# frozenset({44, 5})
# frozenset({24, 43})
# frozenset({24, 44})
# frozenset({35, 27})
# frozenset({43, 27})
# frozenset({27, 44})
# frozenset({43, 35})
# frozenset({35, 44})
# frozenset({43, 44})
# frozenset({5, 7})
# frozenset({5, 14})
# frozenset({18, 5})
# frozenset({5, 46})
# frozenset({5, 47})
# frozenset({14, 7})
# frozenset({18, 7})
# frozenset({46, 7})
# frozenset({47, 7})
# frozenset({18, 14})
# frozenset({46, 14})
# frozenset({14, 47})
# frozenset({18, 46})
# frozenset({18, 47})
# frozenset({46, 47})
# frozenset({48, 6})
# frozenset({49, 6})
# frozenset({50, 6})
# frozenset({23, 7})
# frozenset({31, 7})
# frozenset({48, 7})
# frozenset({49, 7})
# frozenset({50, 7})
# frozenset({8, 18})
# frozenset({8, 23})
# frozenset({8, 31})
# frozenset({8, 48})
# frozenset({8, 49})
# frozenset({8, 50})
# frozenset({48, 18})
# frozenset({49, 18})
# frozenset({18, 50})
# frozenset({48, 23})
# frozenset({49, 23})
# frozenset({50, 23})
# frozenset({48, 31})
# frozenset({49, 31})
# frozenset({50, 31})
# frozenset({48, 49})
# frozenset({48, 50})
# frozenset({49, 50})
# frozenset({2, 13})
# frozenset({13, 6})
# frozenset({25, 6})
# frozenset({25, 13})
# frozenset({26, 13})
# frozenset({17, 6})
# frozenset({51, 6})
# frozenset({17, 51})
# frozenset({18, 51})
# frozenset({52, 15})
# frozenset({53, 15})
# frozenset({54, 15})
# frozenset({52, 53})
# frozenset({52, 54})
# frozenset({53, 54})
# frozenset({2, 5})
# frozenset({5, 6})
# frozenset({25, 5})
# frozenset({4, 13})
# frozenset({4, 55})
# frozenset({13, 55})
# frozenset({17, 25})
# frozenset({8, 13})
# frozenset({34, 6})
# frozenset({48, 34})
# frozenset({58, 6})
# frozenset({59, 6})
# frozenset({58, 59})
# frozenset({10, 22})
# frozenset({27, 6})
# frozenset({9, 17})
# frozenset({9, 18})
# frozenset({9, 27})
# frozenset({9, 29})
# frozenset({9, 49})
# frozenset({9, 50})
# frozenset({17, 27})
# frozenset({17, 29})
# frozenset({17, 49})
# frozenset({17, 50})
# frozenset({18, 27})
# frozenset({27, 29})
# frozenset({49, 27})
# frozenset({50, 27})
# frozenset({49, 29})
# frozenset({50, 29})
# frozenset({1, 14})
# frozenset({1, 60})
# frozenset({60, 14})
# frozenset({10, 5})
# frozenset({13, 5})
# frozenset({41, 5})
# frozenset({42, 5})
# frozenset({60, 5})
# frozenset({61, 5})
# frozenset({10, 13})
# frozenset({10, 14})
# frozenset({10, 60})
# frozenset({10, 61})
# frozenset({13, 14})
# frozenset({41, 13})
# frozenset({42, 13})
# frozenset({60, 13})
# frozenset({61, 13})
# frozenset({41, 14})
# frozenset({42, 14})
# frozenset({61, 14})
# frozenset({41, 60})
# frozenset({41, 61})
# frozenset({42, 60})
# frozenset({42, 61})
# frozenset({60, 61})
# frozenset({62, 6})
# frozenset({26, 62})
# frozenset({65, 5})
# frozenset({0, 10})
# frozenset({0, 31})
# frozenset({10, 31})
# frozenset({25, 10})
# frozenset({10, 44})
# frozenset({25, 18})
# frozenset({18, 44})
# frozenset({18, 61})
# frozenset({25, 44})
# frozenset({25, 61})
# frozenset({44, 61})
# frozenset({65, 18})
# frozenset({13, 22})
# frozenset({50, 13})
# frozenset({50, 22})
# frozenset({66, 53})
# frozenset({4, 7})
# frozenset({4, 14})
# frozenset({17, 4})
# frozenset({25, 4})
# frozenset({48, 4})
# frozenset({67, 4})
# frozenset({6, 14})
# frozenset({67, 6})
# frozenset({17, 7})
# frozenset({25, 7})
# frozenset({29, 7})
# frozenset({30, 7})
# frozenset({67, 7})
# frozenset({17, 14})
# frozenset({25, 14})
# frozenset({29, 14})
# frozenset({14, 30})
# frozenset({48, 14})
# frozenset({67, 14})
# frozenset({17, 30})
# frozenset({48, 17})
# frozenset({17, 67})
# frozenset({18, 67})
# frozenset({25, 29})
# frozenset({25, 30})
# frozenset({48, 25})
# frozenset({25, 67})
# frozenset({48, 29})
# frozenset({67, 29})
# frozenset({48, 30})
# frozenset({67, 30})
# frozenset({48, 67})
# frozenset({2, 20})
# frozenset({10, 26})
# frozenset({10, 68})
# frozenset({10, 70})
# frozenset({26, 14})
# frozenset({68, 14})
# frozenset({70, 14})
# frozenset({41, 26})
# frozenset({26, 68})
# frozenset({26, 70})
# frozenset({41, 68})
# frozenset({41, 70})
# frozenset({68, 70})
# frozenset({10, 4})
# frozenset({4, 71})
# frozenset({6, 71})
# frozenset({10, 21})
# frozenset({10, 71})
# frozenset({17, 21})
# frozenset({17, 71})
# frozenset({21, 71})
# frozenset({33, 10})
# frozenset({33, 14})
# frozenset({9, 5})
# frozenset({12, 5})
# frozenset({48, 5})
# frozenset({52, 5})
# frozenset({5, 71})
# frozenset({12, 6})
# frozenset({52, 6})
# frozenset({9, 12})
# frozenset({48, 9})
# frozenset({9, 52})
# frozenset({9, 71})
# frozenset({48, 12})
# frozenset({12, 52})
# frozenset({12, 71})
# frozenset({48, 52})
# frozenset({48, 71})
# frozenset({52, 71})
# frozenset({43, 30})
# frozenset({52, 30})
# frozenset({53, 30})
# frozenset({43, 52})
# frozenset({43, 53})
# frozenset({0, 50})
# frozenset({2, 14})
# frozenset({11, 6})
# frozenset({2, 55})
# frozenset({43, 6})
# frozenset({44, 6})
# frozenset({18, 43})
# frozenset({48, 43})
# frozenset({48, 44})
# frozenset({2, 58})
# frozenset({58, 13})
# frozenset({0, 7})
# frozenset({0, 13})
# frozenset({0, 18})
# frozenset({18, 13})
# frozenset({75, 6})
# frozenset({8, 75})
# frozenset({75, 13})
# frozenset({0, 52})
# frozenset({2, 43})
# frozenset({2, 52})
# frozenset({43, 21})
# frozenset({52, 21})
# frozenset({8, 70})
# frozenset({25, 49})
# frozenset({0, 11})
# frozenset({10, 11})
# frozenset({11, 13})
# frozenset({0, 8})
# frozenset({0, 67})
# frozenset({0, 78})
# frozenset({1, 6})
# frozenset({8, 1})
# frozenset({1, 18})
# frozenset({24, 1})
# frozenset({1, 35})
# frozenset({1, 52})
# frozenset({1, 67})
# frozenset({1, 78})
# frozenset({8, 2})
# frozenset({2, 67})
# frozenset({2, 78})
# frozenset({24, 6})
# frozenset({35, 6})
# frozenset({78, 6})
# frozenset({8, 24})
# frozenset({8, 35})
# frozenset({8, 52})
# frozenset({8, 67})
# frozenset({8, 78})
# frozenset({24, 18})
# frozenset({18, 35})
# frozenset({18, 52})
# frozenset({18, 78})
# frozenset({24, 52})
# frozenset({24, 67})
# frozenset({24, 78})
# frozenset({35, 52})
# frozenset({67, 35})
# frozenset({35, 78})
# frozenset({67, 52})
# frozenset({52, 78})
# frozenset({67, 78})
# frozenset({11, 22})
# frozenset({0, 20})
# frozenset({0, 80})
# frozenset({2, 10})
# frozenset({80, 2})
# frozenset({10, 20})
# frozenset({80, 10})
# frozenset({20, 13})
# frozenset({80, 13})
# frozenset({80, 20})
# frozenset({40, 14})
# frozenset({50, 14})
# frozenset({40, 50})
# frozenset({41, 50})
# frozenset({4, 28})
# frozenset({4, 36})
# frozenset({40, 4})
# frozenset({4, 54})
# frozenset({17, 28})
# frozenset({32, 17})
# frozenset({17, 36})
# frozenset({40, 17})
# frozenset({17, 54})
# frozenset({32, 28})
# frozenset({28, 36})
# frozenset({40, 28})
# frozenset({28, 54})
# frozenset({32, 36})
# frozenset({32, 40})
# frozenset({32, 54})
# frozenset({40, 36})
# frozenset({36, 54})
# frozenset({40, 54})
# frozenset({65, 2})
# frozenset({65, 20})
# frozenset({10, 12})
# frozenset({48, 10})
# frozenset({17, 12})
# frozenset({18, 12})
# frozenset({25, 12})
# frozenset({82, 6})
# frozenset({25, 82})
# frozenset({8, 80})
# frozenset({80, 52})
# frozenset({0, 14})
# frozenset({0, 25})
# frozenset({0, 48})
# frozenset({0, 59})
# frozenset({0, 60})
# frozenset({48, 2})
# frozenset({2, 59})
# frozenset({2, 60})
# frozenset({59, 4})
# frozenset({4, 60})
# frozenset({80, 4})
# frozenset({59, 14})
# frozenset({80, 14})
# frozenset({25, 59})
# frozenset({25, 60})
# frozenset({80, 25})
# frozenset({48, 59})
# frozenset({48, 60})
# frozenset({48, 80})
# frozenset({59, 60})
# frozenset({80, 59})
# frozenset({80, 60})
# frozenset({40, 2})
# frozenset({40, 25})
# frozenset({8, 33})
# frozenset({8, 85})
# frozenset({48, 33})
# frozenset({33, 85})
# frozenset({48, 85})
# frozenset({2, 53})
# frozenset({53, 6})
# frozenset({80, 6})
# frozenset({18, 53})
# frozenset({80, 18})
# frozenset({48, 53})
# frozenset({80, 53})
# frozenset({68, 6})
# frozenset({67, 21})
# frozenset({68, 21})
# frozenset({67, 68})
# frozenset({2, 7})
# frozenset({67, 5})
# frozenset({24, 7})
# frozenset({35, 7})
# frozenset({24, 14})
# frozenset({35, 14})
# frozenset({11, 14})
# frozenset({35, 11})
# frozenset({58, 11})
# frozenset({66, 11})
# frozenset({21, 14})
# frozenset({58, 14})
# frozenset({66, 14})
# frozenset({35, 21})
# frozenset({58, 21})
# frozenset({66, 21})
# frozenset({24, 58})
# frozenset({24, 66})
# frozenset({26, 35})
# frozenset({26, 58})
# frozenset({26, 66})
# frozenset({58, 35})
# frozenset({66, 35})
# frozenset({58, 66})
# frozenset({6, 22})
# frozenset({6, 47})
# frozenset({6, 87})
# frozenset({13, 47})
# frozenset({13, 87})
# frozenset({18, 87})
# frozenset({25, 22})
# frozenset({22, 47})
# frozenset({22, 87})
# frozenset({25, 47})
# frozenset({25, 50})
# frozenset({25, 87})
# frozenset({50, 47})
# frozenset({87, 47})
# frozenset({50, 87})
# frozenset({0, 28})
# frozenset({0, 47})
# frozenset({0, 88})
# frozenset({28, 47})
# frozenset({88, 28})
# frozenset({88, 47})
# frozenset({2, 11})
# frozenset({11, 78})
# frozenset({25, 78})
# frozenset({2, 42})
# frozenset({26, 42})
# frozenset({4, 44})
# frozenset({4, 52})
# frozenset({44, 23})
# frozenset({52, 23})
# frozenset({44, 52})
# frozenset({10, 43})
# frozenset({10, 67})
# frozenset({43, 13})
# frozenset({67, 13})
# frozenset({67, 43})
# frozenset({0, 30})
# frozenset({88, 2})
# frozenset({88, 6})
# frozenset({80, 7})
# frozenset({88, 7})
# frozenset({88, 14})
# frozenset({88, 25})
# frozenset({80, 30})
# frozenset({88, 30})
# frozenset({80, 88})
# frozenset({49, 30})
# frozenset({0, 17})
# frozenset({0, 42})
# frozenset({17, 2})
# frozenset({11, 7})
# frozenset({42, 7})
# frozenset({17, 11})
# frozenset({18, 11})
# frozenset({42, 11})
# frozenset({17, 13})
# frozenset({24, 13})
# frozenset({35, 13})
# frozenset({24, 17})
# frozenset({17, 35})
# frozenset({17, 42})
# frozenset({24, 42})
# frozenset({25, 42})
# frozenset({42, 35})
# frozenset({33, 6})
# frozenset({43, 12})
# frozenset({58, 12})
# frozenset({12, 70})
# frozenset({18, 58})
# frozenset({18, 70})
# frozenset({58, 43})
# frozenset({43, 70})
# frozenset({48, 58})
# frozenset({48, 70})
# frozenset({58, 70})
# frozenset({10, 85})
# frozenset({36, 6})
# frozenset({13, 30})
# frozenset({36, 13})
# frozenset({88, 13})
# frozenset({17, 26})
# frozenset({17, 47})
# frozenset({88, 17})
# frozenset({18, 36})
# frozenset({88, 18})
# frozenset({26, 36})
# frozenset({26, 47})
# frozenset({88, 26})
# frozenset({36, 30})
# frozenset({42, 30})
# frozenset({30, 47})
# frozenset({42, 36})
# frozenset({36, 47})
# frozenset({88, 36})
# frozenset({42, 47})
# frozenset({88, 42})
# frozenset({49, 2})
# frozenset({49, 4})
# frozenset({88, 4})
# frozenset({88, 49})
# frozenset({1, 15})
# frozenset({1, 17})
# frozenset({48, 1})
# frozenset({1, 53})
# frozenset({88, 1})
# frozenset({6, 15})
# frozenset({17, 15})
# frozenset({48, 15})
# frozenset({67, 15})
# frozenset({88, 15})
# frozenset({17, 53})
# frozenset({48, 88})
# frozenset({67, 53})
# frozenset({88, 53})
# frozenset({88, 67})
# frozenset({2, 68})
# frozenset({21, 7})
# frozenset({34, 7})
# frozenset({58, 7})
# frozenset({68, 7})
# frozenset({34, 14})
# frozenset({49, 14})
# frozenset({18, 21})
# frozenset({18, 34})
# frozenset({18, 68})
# frozenset({34, 21})
# frozenset({49, 21})
# frozenset({25, 58})
# frozenset({25, 68})
# frozenset({49, 34})
# frozenset({34, 58})
# frozenset({34, 68})
# frozenset({49, 58})
# frozenset({49, 68})
# frozenset({58, 68})
# frozenset({2, 38})
# frozenset({2, 61})
# frozenset({5, 30})
# frozenset({5, 38})
# frozenset({38, 6})
# frozenset({61, 6})
# frozenset({38, 7})
# frozenset({61, 7})
# frozenset({13, 38})
# frozenset({18, 38})
# frozenset({25, 38})
# frozenset({38, 30})
# frozenset({61, 30})
# frozenset({61, 38})
# frozenset({67, 38})
# frozenset({67, 61})
# frozenset({2, 93})
# frozenset({93, 6})
# frozenset({17, 93})
# frozenset({24, 48})
# frozenset({24, 93})
# frozenset({25, 93})
# frozenset({48, 35})
# frozenset({35, 93})
# frozenset({48, 93})
# frozenset({24, 4})
# frozenset({35, 4})
# frozenset({58, 4})
# frozenset({58, 30})
# frozenset({85, 6})
# frozenset({22, 7})
# frozenset({51, 7})
# frozenset({82, 7})
# frozenset({85, 7})
# frozenset({9, 14})
# frozenset({9, 22})
# frozenset({9, 25})
# frozenset({9, 42})
# frozenset({9, 51})
# frozenset({9, 82})
# frozenset({9, 85})
# frozenset({14, 22})
# frozenset({51, 14})
# frozenset({82, 14})
# frozenset({85, 14})
# frozenset({42, 22})
# frozenset({51, 22})
# frozenset({82, 22})
# frozenset({85, 22})
# frozenset({25, 51})
# frozenset({25, 85})
# frozenset({42, 51})
# frozenset({42, 82})
# frozenset({42, 85})
# frozenset({82, 51})
# frozenset({51, 85})
# frozenset({82, 85})
# frozenset({0, 9})
# frozenset({0, 74})
# frozenset({9, 2})
# frozenset({2, 74})
# frozenset({74, 6})
# frozenset({74, 7})
# frozenset({9, 74})
# frozenset({6, 95})
# frozenset({49, 61})
# frozenset({49, 95})
# frozenset({58, 61})
# frozenset({58, 95})
# frozenset({61, 95})
# frozenset({24, 10})
# frozenset({10, 35})
# frozenset({18, 60})
# frozenset({24, 60})
# frozenset({35, 60})
# frozenset({15, 7})
# frozenset({18, 15})
# frozenset({21, 15})
# frozenset({34, 15})
# frozenset({48, 21})
# frozenset({34, 67})
# frozenset({28, 5})
# frozenset({28, 7})
# frozenset({43, 7})
# frozenset({28, 13})
# frozenset({18, 28})
# frozenset({43, 28})
# frozenset({67, 12})
# frozenset({24, 51})
# frozenset({51, 35})
# frozenset({10, 75})
# frozenset({52, 7})
# frozenset({2, 47})
# frozenset({2, 82})
# frozenset({2, 85})
# frozenset({4, 20})
# frozenset({4, 47})
# frozenset({82, 4})
# frozenset({4, 85})
# frozenset({20, 5})
# frozenset({5, 31})
# frozenset({82, 5})
# frozenset({85, 5})
# frozenset({88, 5})
# frozenset({20, 7})
# frozenset({20, 14})
# frozenset({14, 31})
# frozenset({52, 14})
# frozenset({20, 31})
# frozenset({20, 47})
# frozenset({48, 20})
# frozenset({20, 52})
# frozenset({82, 20})
# frozenset({20, 85})
# frozenset({88, 20})
# frozenset({47, 31})
# frozenset({52, 31})
# frozenset({82, 31})
# frozenset({85, 31})
# frozenset({88, 31})
# frozenset({48, 47})
# frozenset({52, 47})
# frozenset({82, 47})
# frozenset({85, 47})
# frozenset({48, 82})
# frozenset({82, 52})
# frozenset({52, 85})
# frozenset({88, 52})
# frozenset({88, 82})
# frozenset({88, 85})
# frozenset({11, 36})
# frozenset({11, 55})
# frozenset({36, 55})
# frozenset({42, 55})
# frozenset({17, 66})
# frozenset({26, 51})
# frozenset({51, 27})
# frozenset({66, 27})
# frozenset({66, 51})
# frozenset({27, 38})
# frozenset({27, 52})
# frozenset({58, 27})
# frozenset({33, 38})
# frozenset({33, 52})
# frozenset({33, 58})
# frozenset({52, 38})
# frozenset({58, 38})
# frozenset({58, 52})
# frozenset({0, 66})
# frozenset({66, 6})
# frozenset({66, 7})
# frozenset({25, 66})
# frozenset({48, 66})
# frozenset({10, 59})
# frozenset({40, 78})
# frozenset({50, 78})
# frozenset({25, 41})
# frozenset({17, 60})
# frozenset({44, 7})
# frozenset({44, 13})
# frozenset({24, 20})
# frozenset({35, 20})
# frozenset({20, 44})
# frozenset({48, 46})
# frozenset({2, 98})
# frozenset({98, 20})
# frozenset({9, 4})
# frozenset({1, 12})
# frozenset({1, 21})
# frozenset({1, 22})
# frozenset({1, 26})
# frozenset({73, 1})
# frozenset({12, 14})
# frozenset({12, 21})
# frozenset({12, 22})
# frozenset({26, 12})
# frozenset({33, 12})
# frozenset({73, 12})
# frozenset({73, 14})
# frozenset({33, 18})
# frozenset({73, 18})
# frozenset({21, 22})
# frozenset({33, 21})
# frozenset({73, 21})
# frozenset({26, 22})
# frozenset({33, 22})
# frozenset({48, 22})
# frozenset({73, 22})
# frozenset({33, 26})
# frozenset({48, 26})
# frozenset({73, 26})
# frozenset({73, 33})
# frozenset({48, 73})
# frozenset({88, 21})
# frozenset({2, 22})
# frozenset({2, 66})
# frozenset({29, 13})
# frozenset({66, 13})
# frozenset({13, 78})
# frozenset({18, 66})
# frozenset({29, 22})
# frozenset({66, 22})
# frozenset({67, 22})
# frozenset({78, 22})
# frozenset({42, 29})
# frozenset({66, 29})
# frozenset({29, 78})
# frozenset({42, 66})
# frozenset({42, 67})
# frozenset({42, 78})
# frozenset({66, 67})
# frozenset({66, 78})
# frozenset({34, 27})
# frozenset({27, 60})
# frozenset({34, 60})
# frozenset({73, 13})
# frozenset({0, 34})
# frozenset({0, 40})
# frozenset({40, 34})
# frozenset({8, 30})
# frozenset({8, 61})
# frozenset({49, 13})
# frozenset({24, 30})
# frozenset({24, 49})
# frozenset({24, 61})
# frozenset({35, 30})
# frozenset({78, 30})
# frozenset({49, 35})
# frozenset({35, 61})
# frozenset({49, 78})
# frozenset({61, 78})
# frozenset({4, 70})
# frozenset({70, 6})
# frozenset({41, 2})
# frozenset({8, 14})
# frozenset({8, 26})
# frozenset({8, 41})
# frozenset({8, 55})
# frozenset({8, 58})
# frozenset({14, 55})
# frozenset({26, 55})
# frozenset({41, 55})
# frozenset({41, 58})
# frozenset({58, 55})
# frozenset({73, 25})
# frozenset({1, 4})
# frozenset({60, 6})
# frozenset({102, 6})
# frozenset({25, 102})
# frozenset({48, 102})
# frozenset({60, 102})
# frozenset({17, 95})
# frozenset({50, 95})
# frozenset({34, 30})
# frozenset({34, 52})
# frozenset({10, 62})
# frozenset({12, 61})
# frozenset({12, 62})
# frozenset({61, 62})
# frozenset({67, 62})
# frozenset({67, 20})
# frozenset({20, 87})
# frozenset({67, 87})
# frozenset({42, 21})
# frozenset({48, 42})
# frozenset({2, 50})
# frozenset({24, 31})
# frozenset({0, 102})
# frozenset({27, 4})
# frozenset({43, 4})
# frozenset({4, 102})
# frozenset({9, 30})
# frozenset({9, 43})
# frozenset({9, 102})
# frozenset({25, 43})
# frozenset({27, 30})
# frozenset({27, 102})
# frozenset({102, 30})
# frozenset({43, 102})
# frozenset({0, 58})
# frozenset({58, 47})
# frozenset({67, 47})
# frozenset({58, 67})
# frozenset({51, 12})
# frozenset({62, 14})
# frozenset({18, 62})
# frozenset({33, 51})
# frozenset({33, 62})
# frozenset({33, 70})
# frozenset({48, 51})
# frozenset({48, 62})
# frozenset({51, 62})
# frozenset({51, 70})
# frozenset({70, 62})
# frozenset({9, 58})
# frozenset({10, 50})
# frozenset({10, 58})
# frozenset({50, 58})
# frozenset({5, 23})
# frozenset({51, 5})
# frozenset({10, 23})
# frozenset({10, 51})
# frozenset({14, 23})
# frozenset({51, 23})
# frozenset({27, 12})
# frozenset({1, 25})
# frozenset({1, 95})
# frozenset({18, 95})
# frozenset({25, 95})
# frozenset({24, 29})
# frozenset({24, 88})
# frozenset({35, 29})
# frozenset({58, 29})
# frozenset({61, 29})
# frozenset({88, 29})
# frozenset({88, 35})
# frozenset({88, 58})
# frozenset({88, 61})
# frozenset({60, 47})
# frozenset({50, 35})
# frozenset({25, 23})
# frozenset({36, 23})
# frozenset({38, 23})
# frozenset({47, 23})
# frozenset({54, 23})
# frozenset({66, 23})
# frozenset({67, 23})
# frozenset({78, 23})
# frozenset({25, 54})
# frozenset({36, 38})
# frozenset({66, 36})
# frozenset({67, 36})
# frozenset({36, 78})
# frozenset({38, 47})
# frozenset({54, 38})
# frozenset({66, 38})
# frozenset({78, 38})
# frozenset({54, 47})
# frozenset({66, 47})
# frozenset({78, 47})
# frozenset({66, 54})
# frozenset({67, 54})
# frozenset({78, 54})
# frozenset({10, 34})
# frozenset({10, 38})
# frozenset({10, 78})
# frozenset({10, 95})
# frozenset({34, 38})
# frozenset({34, 78})
# frozenset({34, 95})
# frozenset({60, 38})
# frozenset({38, 95})
# frozenset({60, 78})
# frozenset({60, 95})
# frozenset({78, 95})
# frozenset({0, 26})
# frozenset({0, 33})
# frozenset({58, 78})
# frozenset({8, 36})
# frozenset({40, 67})
# frozenset({50, 21})
# frozenset({10, 36})
# frozenset({0, 29})
# frozenset({11, 29})
# frozenset({34, 11})
# frozenset({34, 13})
# frozenset({34, 29})
# frozenset({2, 70})
# frozenset({42, 70})
# frozenset({70, 47})
# frozenset({49, 10})
# frozenset({13, 23})
# frozenset({60, 23})
# frozenset({49, 60})
# frozenset({49, 43})
# frozenset({2, 12})
# frozenset({42, 12})
# frozenset({42, 52})
# frozenset({2, 44})
# frozenset({55, 7})
# frozenset({25, 55})
# frozenset({44, 55})
# frozenset({80, 44})
# frozenset({80, 55})
# frozenset({41, 12})
# frozenset({28, 6})
# frozenset({49, 28})
# frozenset({25, 20})
# frozenset({24, 23})
# frozenset({75, 23})
# frozenset({24, 75})
# frozenset({26, 75})
# frozenset({58, 36})
# frozenset({5, 62})
# frozenset({13, 62})
# frozenset({28, 62})
# frozenset({2, 28})
# frozenset({10, 28})
# frozenset({10, 52})
# frozenset({88, 10})
# frozenset({11, 52})
# frozenset({88, 11})
# frozenset({28, 52})
# frozenset({48, 13})
# frozenset({52, 13})
# frozenset({17, 52})
# frozenset({48, 36})
# frozenset({36, 52})
# frozenset({21, 23})
# frozenset({34, 23})
# frozenset({43, 23})
# frozenset({34, 43})
# frozenset({11, 20})
# frozenset({11, 47})
# frozenset({0, 65})
# frozenset({65, 27})
# frozenset({65, 29})
# frozenset({26, 52})
# frozenset({65, 43})
# frozenset({88, 43})
# frozenset({88, 65})
# frozenset({65, 6})
# frozenset({49, 12})
# frozenset({12, 60})
# frozenset({65, 12})
# frozenset({49, 51})
# frozenset({65, 49})
# frozenset({49, 70})
# frozenset({51, 60})
# frozenset({65, 51})
# frozenset({65, 60})
# frozenset({60, 70})
# frozenset({65, 70})
# frozenset({0, 23})
# frozenset({54, 22})
# frozenset({17, 38})
# frozenset({17, 78})
# frozenset({51, 38})
# frozenset({51, 78})
# frozenset({25, 53})
# frozenset({27, 61})
# frozenset({0, 68})
# frozenset({4, 68})
# frozenset({68, 23})
# frozenset({88, 23})
# frozenset({48, 68})
# frozenset({88, 68})
# frozenset({4, 109})
# frozenset({85, 13})
# frozenset({109, 13})
# frozenset({48, 109})
# frozenset({109, 85})
# frozenset({43, 36})
# frozenset({20, 6})
# frozenset({38, 14})
# frozenset({34, 20})
# frozenset({20, 38})
# frozenset({49, 26})
# frozenset({1, 5})
# frozenset({1, 29})
# frozenset({1, 30})
# frozenset({29, 5})
# frozenset({0, 15})
# frozenset({0, 22})
# frozenset({0, 38})
# frozenset({2, 15})
# frozenset({4, 15})
# frozenset({4, 22})
# frozenset({4, 38})
# frozenset({42, 4})
# frozenset({22, 15})
# frozenset({38, 15})
# frozenset({42, 15})
# frozenset({47, 15})
# frozenset({38, 22})
# frozenset({52, 22})
# frozenset({42, 38})
# frozenset({48, 38})
# frozenset({40, 13})
# frozenset({13, 95})
# frozenset({40, 95})
# frozenset({66, 5})
# frozenset({18, 75})
# frozenset({25, 75})
# frozenset({75, 51})
# frozenset({82, 29})
# frozenset({98, 29})
# frozenset({82, 98})
# frozenset({9, 13})
# frozenset({9, 60})
# frozenset({2, 87})
# frozenset({58, 87})
# frozenset({10, 30})
# frozenset({22, 30})
# frozenset({26, 50})
# frozenset({10, 66})
# frozenset({66, 30})
# frozenset({49, 66})
# frozenset({13, 71})
# frozenset({27, 22})
# frozenset({49, 22})
# frozenset({22, 71})
# frozenset({25, 71})
# frozenset({26, 71})
# frozenset({48, 27})
# frozenset({27, 71})
# frozenset({49, 71})
# frozenset({50, 71})
# frozenset({9, 26})
# frozenset({88, 9})
# frozenset({88, 33})
# frozenset({12, 93})
# frozenset({51, 43})
# frozenset({43, 93})
# frozenset({51, 52})
# frozenset({51, 93})
# frozenset({52, 93})
# frozenset({1, 49})
# frozenset({24, 12})
# frozenset({88, 12})
# frozenset({51, 109})
# frozenset({60, 7})
# frozenset({60, 21})
# frozenset({53, 7})
# frozenset({2, 71})
# frozenset({24, 71})
# frozenset({8, 17})
# frozenset({8, 27})
# frozenset({8, 38})
# frozenset({10, 27})
# frozenset({10, 55})
# frozenset({32, 10})
# frozenset({10, 87})
# frozenset({17, 23})
# frozenset({17, 87})
# frozenset({27, 23})
# frozenset({87, 23})
# frozenset({32, 27})
# frozenset({27, 87})
# frozenset({32, 48})
# frozenset({32, 87})
# frozenset({48, 87})
# frozenset({1, 43})
# frozenset({2, 75})
# frozenset({75, 4})
# frozenset({4, 78})
# frozenset({10, 47})
# frozenset({75, 14})
# frozenset({78, 14})
# frozenset({17, 75})
# frozenset({75, 30})
# frozenset({42, 75})
# frozenset({75, 47})
# frozenset({75, 78})
# frozenset({88, 75})
# frozenset({88, 78})
# frozenset({49, 11})
# frozenset({0, 62})
# frozenset({62, 7})
# frozenset({9, 62})
# frozenset({25, 62})
# frozenset({49, 36})
# frozenset({34, 42})
# frozenset({14, 95})
# frozenset({53, 14})
# frozenset({80, 17})
# frozenset({80, 67})
# frozenset({49, 59})
# frozenset({11, 23})
# frozenset({50, 11})
# frozenset({55, 23})
# frozenset({55, 47})
# frozenset({50, 55})
# frozenset({34, 28})
# frozenset({42, 28})
# frozenset({48, 28})
# frozenset({88, 34})
# frozenset({34, 75})
# frozenset({75, 60})
# frozenset({22, 23})
# frozenset({46, 22})
# frozenset({42, 23})
# frozenset({46, 23})
# frozenset({42, 46})
# frozenset({2, 51})
# frozenset({67, 51})
# frozenset({20, 23})
# frozenset({20, 60})
# frozenset({74, 54})
# frozenset({50, 4})
# frozenset({32, 21})
# frozenset({32, 50})
# frozenset({78, 7})
# frozenset({43, 14})
# frozenset({17, 43})
# frozenset({43, 78})
# frozenset({67, 70})
# frozenset({13, 102})
# frozenset({58, 102})
# frozenset({66, 4})
# frozenset({17, 58})
# frozenset({98, 6})
# frozenset({98, 30})
# frozenset({27, 14})
# frozenset({26, 43})
# frozenset({24, 33})
# frozenset({24, 82})
# frozenset({33, 34})
# frozenset({33, 82})
# frozenset({34, 82})
# frozenset({40, 7})
# frozenset({40, 11})
# frozenset({42, 50})
# frozenset({2, 109})
# frozenset({109, 7})
# frozenset({9, 109})
# frozenset({109, 14})
# frozenset({17, 109})
# frozenset({25, 109})
# frozenset({50, 109})
# frozenset({33, 2})
# frozenset({33, 11})
# frozenset({11, 70})
# frozenset({28, 14})
# frozenset({21, 70})
# frozenset({24, 70})
# frozenset({33, 28})
# frozenset({28, 70})
# frozenset({52, 70})
# frozenset({18, 85})
# frozenset({24, 40})
# frozenset({24, 85})
# frozenset({40, 43})
# frozenset({40, 48})
# frozenset({40, 52})
# frozenset({40, 85})
# frozenset({43, 85})
# frozenset({48, 11})
# frozenset({51, 11})
# frozenset({34, 51})
# frozenset({40, 51})
# frozenset({59, 11})
# frozenset({11, 87})
# frozenset({59, 13})
# frozenset({59, 87})
# frozenset({58, 20})
# frozenset({11, 30})
# frozenset({80, 11})
# frozenset({58, 22})
# frozenset({80, 22})
# frozenset({80, 58})
# frozenset({75, 7})
# frozenset({25, 52})
# frozenset({75, 52})
# frozenset({24, 9})
# frozenset({17, 22})
# frozenset({24, 22})
# frozenset({53, 22})
# frozenset({53, 23})
# frozenset({24, 53})
# frozenset({10, 15})
# frozenset({10, 53})
# frozenset({10, 74})
# frozenset({28, 15})
# frozenset({40, 15})
# frozenset({68, 15})
# frozenset({74, 15})
# frozenset({28, 53})
# frozenset({28, 68})
# frozenset({74, 28})
# frozenset({40, 53})
# frozenset({40, 68})
# frozenset({40, 74})
# frozenset({52, 68})
# frozenset({74, 52})
# frozenset({68, 53})
# frozenset({74, 53})
# frozenset({74, 68})
# frozenset({8, 25})
# frozenset({29, 21})
# frozenset({10, 98})
# frozenset({98, 11})
# frozenset({50, 28})
# frozenset({98, 28})
# frozenset({34, 50})
# frozenset({34, 98})
# frozenset({88, 50})
# frozenset({50, 98})
# frozenset({88, 98})
# frozenset({49, 42})
# frozenset({42, 58})
# frozenset({49, 52})
# frozenset({17, 46})
# frozenset({17, 85})
# frozenset({18, 54})
# frozenset({35, 23})
# frozenset({85, 23})
# frozenset({24, 46})
# frozenset({24, 54})
# frozenset({35, 46})
# frozenset({35, 54})
# frozenset({35, 85})
# frozenset({49, 46})
# frozenset({54, 46})
# frozenset({66, 46})
# frozenset({85, 46})
# frozenset({49, 54})
# frozenset({49, 85})
# frozenset({85, 54})
# frozenset({66, 85})
# frozenset({9, 59})
# frozenset({9, 67})
# frozenset({9, 98})
# frozenset({17, 59})
# frozenset({17, 98})
# frozenset({18, 59})
# frozenset({18, 98})
# frozenset({48, 98})
# frozenset({67, 59})
# frozenset({98, 59})
# frozenset({98, 67})
# frozenset({11, 4})
# frozenset({52, 60})
# frozenset({58, 60})
# frozenset({40, 22})
# frozenset({61, 22})
# frozenset({40, 61})
# frozenset({40, 66})
# frozenset({66, 61})
# frozenset({0, 55})
# frozenset({27, 20})
# frozenset({20, 36})
# frozenset({27, 36})
# frozenset({53, 13})
# frozenset({13, 54})
# frozenset({20, 53})
# frozenset({20, 54})
# frozenset({34, 47})
# frozenset({34, 53})
# frozenset({34, 54})
# frozenset({53, 47})
# frozenset({26, 20})
# frozenset({59, 7})
# frozenset({24, 59})
# frozenset({1, 10})
# frozenset({1, 75})
# frozenset({26, 67})
# frozenset({24, 50})
# frozenset({50, 60})
# frozenset({0, 36})
# frozenset({36, 7})
# frozenset({36, 14})
# frozenset({34, 4})
# frozenset({17, 74})
# frozenset({40, 26})
# frozenset({26, 74})
# frozenset({40, 30})
# frozenset({74, 30})
# frozenset({40, 58})
# frozenset({58, 74})
# frozenset({8, 43})
# frozenset({44, 21})
# frozenset({21, 62})
# frozenset({80, 21})
# frozenset({33, 44})
# frozenset({80, 33})
# frozenset({44, 62})
# frozenset({80, 62})
# frozenset({26, 7})
# frozenset({29, 47})
# frozenset({49, 47})
# frozenset({73, 6})
# frozenset({9, 11})
# frozenset({73, 9})
# frozenset({73, 11})
# frozenset({73, 52})
# frozenset({18, 93})
# frozenset({80, 23})
# frozenset({93, 23})
# frozenset({80, 42})
# frozenset({42, 93})
# frozenset({80, 93})
# frozenset({2, 95})
# frozenset({12, 36})
# frozenset({9, 21})
# frozenset({9, 38})
# frozenset({9, 47})
# frozenset({11, 38})
# frozenset({21, 38})
# frozenset({21, 47})
# frozenset({43, 20})
# frozenset({75, 20})
# frozenset({75, 43})
# frozenset({49, 20})
# frozenset({59, 20})
# frozenset({59, 22})
# frozenset({9, 36})
# frozenset({9, 87})
# frozenset({36, 22})
# frozenset({36, 87})
# frozenset({17, 44})
# frozenset({36, 44})
# frozenset({9, 28})
# frozenset({75, 11})
# frozenset({49, 75})
# frozenset({70, 7})
# frozenset({24, 80})
# frozenset({80, 28})
# frozenset({21, 30})
# frozenset({11, 71})
# frozenset({51, 20})
# frozenset({60, 22})
# frozenset({33, 36})
# frozenset({33, 50})
# frozenset({50, 36})
# frozenset({50, 44})
# frozenset({1, 46})
# frozenset({4, 46})
# frozenset({75, 46})
# frozenset({50, 52})
# frozenset({36, 53})
# frozenset({0, 109})
# frozenset({109, 6})
# frozenset({18, 109})
# frozenset({17, 68})
# frozenset({58, 15})
# frozenset({13, 46})
# frozenset({74, 14})
# frozenset({50, 74})
# frozenset({65, 26})
# frozenset({8, 5})
# frozenset({43, 11})
# frozenset({11, 68})
# frozenset({50, 43})
# frozenset({43, 68})
# frozenset({50, 68})
# frozenset({42, 43})
# frozenset({13, 70})
# frozenset({44, 46})
# frozenset({24, 32})
# frozenset({24, 47})
# frozenset({24, 109})
# frozenset({26, 109})
# frozenset({32, 47})
# frozenset({32, 67})
# frozenset({32, 109})
# frozenset({109, 47})
# frozenset({67, 109})
# frozenset({65, 7})
# frozenset({51, 13})
# frozenset({65, 13})
# frozenset({65, 23})
# frozenset({48, 65})
# frozenset({50, 51})
# frozenset({65, 50})
# frozenset({36, 15})
# frozenset({74, 4})
# frozenset({18, 74})
# frozenset({52, 29})
# frozenset({74, 29})
# frozenset({20, 55})
# frozenset({12, 7})
# frozenset({12, 23})
# frozenset({12, 29})
# frozenset({36, 29})
# frozenset({21, 5})
# frozenset({59, 5})
# frozenset({75, 5})
# frozenset({51, 21})
# frozenset({59, 21})
# frozenset({75, 21})
# frozenset({59, 51})
# frozenset({75, 59})
# frozenset({40, 70})
# frozenset({9, 34})
# frozenset({46, 6})
# frozenset({25, 46})
# frozenset({67, 46})
# frozenset({2, 46})
# frozenset({21, 13})
# frozenset({21, 46})
# frozenset({11, 12})
# frozenset({67, 11})
# frozenset({75, 12})
# frozenset({75, 67})
# frozenset({59, 68})
# frozenset({8, 4})
# frozenset({4, 61})
# frozenset({4, 95})
# frozenset({8, 95})
# frozenset({43, 61})
# frozenset({43, 95})
# frozenset({0, 70})
# frozenset({0, 93})
# frozenset({4, 93})
# frozenset({93, 21})
# frozenset({93, 70})
# frozenset({9, 23})
# frozenset({58, 23})
# frozenset({25, 15})
# frozenset({26, 15})
# frozenset({43, 15})
# frozenset({6, 55})
# frozenset({9, 46})
# frozenset({9, 75})
# frozenset({43, 46})
# frozenset({48, 74})
# frozenset({26, 5})
# frozenset({26, 38})
# frozenset({25, 31})
# frozenset({38, 31})
# frozenset({42, 31})
# frozenset({78, 31})
# frozenset({48, 78})
# frozenset({11, 46})
# frozenset({28, 46})
# frozenset({58, 28})
# frozenset({58, 46})
# frozenset({17, 31})
# frozenset({21, 31})
# frozenset({40, 21})
# frozenset({74, 21})
# frozenset({21, 95})
# frozenset({30, 95})
# frozenset({40, 31})
# frozenset({67, 31})
# frozenset({74, 31})
# frozenset({95, 31})
# frozenset({40, 49})
# frozenset({49, 67})
# frozenset({49, 74})
# frozenset({52, 95})
# frozenset({74, 67})
# frozenset({67, 95})
# frozenset({74, 95})
# frozenset({24, 74})
# frozenset({25, 74})
# frozenset({50, 53})
# frozenset({8, 11})
# frozenset({8, 21})
# frozenset({8, 40})
# frozenset({8, 42})
# frozenset({8, 47})
# frozenset({40, 47})
# frozenset({51, 4})
# frozenset({73, 4})
# frozenset({73, 50})
# frozenset({24, 38})
# frozenset({82, 36})
# frozenset({82, 38})
# frozenset({58, 51})
# frozenset({13, 15})
# frozenset({24, 15})
# frozenset({44, 15})
# frozenset({51, 15})
# frozenset({26, 44})
# frozenset({51, 44})
# frozenset({67, 44})
# frozenset({73, 7})
# frozenset({12, 47})
# frozenset({12, 78})
# frozenset({80, 12})
# frozenset({73, 17})
# frozenset({73, 47})
# frozenset({80, 47})
# frozenset({73, 67})
# frozenset({73, 78})
# frozenset({80, 73})
# frozenset({80, 78})
# frozenset({11, 93})
# frozenset({68, 93})
# frozenset({88, 93})
# frozenset({8, 44})
# frozenset({26, 61})
# frozenset({40, 44})
# frozenset({48, 61})
# frozenset({22, 95})
# frozenset({9, 53})
# frozenset({9, 78})
# frozenset({60, 53})
# frozenset({53, 78})
# frozenset({0, 51})
# frozenset({65, 4})
# frozenset({80, 5})
# frozenset({80, 51})
# frozenset({65, 52})
# frozenset({80, 65})
# frozenset({0, 12})
# frozenset({8, 12})
# frozenset({11, 44})
# frozenset({42, 44})
# frozenset({49, 44})
# frozenset({75, 44})
# frozenset({0, 73})
# frozenset({73, 2})
# frozenset({0, 32})
# frozenset({32, 12})
# frozenset({80, 26})
# frozenset({51, 29})
# frozenset({80, 29})
# frozenset({32, 51})
# frozenset({32, 58})
# frozenset({32, 80})
# frozenset({80, 1})
# frozenset({8, 15})
# frozenset({8, 28})
# frozenset({11, 15})
# frozenset({12, 15})
# frozenset({12, 28})
# frozenset({67, 28})
# frozenset({2, 27})
# frozenset({2, 102})
# frozenset({27, 46})
# frozenset({102, 46})
# frozenset({49, 102})
# frozenset({9, 95})
# frozenset({95, 47})
# frozenset({43, 87})
# frozenset({41, 11})
# frozenset({34, 12})
# frozenset({0, 46})
# frozenset({60, 46})
# frozenset({71, 7})
# frozenset({18, 71})
# frozenset({71, 23})
# frozenset({71, 31})
# frozenset({78, 71})
# frozenset({20, 21})
# frozenset({74, 51})
# frozenset({65, 17})
# frozenset({65, 25})
# frozenset({48, 54})
# frozenset({65, 54})
# frozenset({42, 27})
# frozenset({67, 27})
# frozenset({29, 46})
# frozenset({52, 46})
# frozenset({9, 20})
# frozenset({50, 20})
# frozenset({59, 43})
# frozenset({50, 59})
# frozenset({50, 75})
# frozenset({8, 22})
# frozenset({41, 22})
# frozenset({93, 7})
# frozenset({10, 93})
# frozenset({26, 93})
# frozenset({11, 85})
# frozenset({12, 85})
# frozenset({33, 67})
# frozenset({67, 85})
# frozenset({82, 15})
# frozenset({26, 34})
# frozenset({26, 82})
# frozenset({28, 38})
# frozenset({82, 28})
# frozenset({74, 11})
# frozenset({12, 46})
# frozenset({74, 12})
# frozenset({74, 46})
# frozenset({73, 74})
# frozenset({18, 55})
# frozenset({27, 55})
# frozenset({10, 46})
# frozenset({43, 47})
# frozenset({78, 46})
# frozenset({17, 5})
# frozenset({58, 5})
# frozenset({65, 46})
# frozenset({65, 58})
# frozenset({65, 67})
# frozenset({24, 55})
# frozenset({74, 27})
# frozenset({43, 55})
# frozenset({74, 43})
# frozenset({67, 55})
# frozenset({74, 55})
# frozenset({0, 87})
# frozenset({65, 11})
# frozenset({11, 95})
# frozenset({36, 5})
# frozenset({0, 49})
# frozenset({80, 27})
# frozenset({80, 49})
# frozenset({17, 62})
# frozenset({25, 98})
# frozenset({98, 38})
# frozenset({1, 93})
# frozenset({60, 93})
# frozenset({17, 20})
# frozenset({42, 20})
# frozenset({73, 10})
# frozenset({73, 75})
# frozenset({14, 71})
# frozenset({49, 5})
# frozenset({50, 5})
# frozenset({35, 87})
# frozenset({48, 75})
# frozenset({10, 102})
# frozenset({36, 102})
# frozenset({50, 102})
# frozenset({33, 4})
# frozenset({51, 28})
# frozenset({28, 61})
# frozenset({51, 61})
# frozenset({0, 41})
# frozenset({0, 95})
# frozenset({10, 109})
# frozenset({33, 41})
# frozenset({33, 42})
# frozenset({33, 74})
# frozenset({33, 95})
# frozenset({33, 109})
# frozenset({41, 74})
# frozenset({41, 95})
# frozenset({41, 109})
# frozenset({42, 74})
# frozenset({42, 95})
# frozenset({42, 109})
# frozenset({74, 109})
# frozenset({109, 95})
# frozenset({32, 7})
# frozenset({46, 30})
# frozenset({109, 30})
# frozenset({32, 46})
# frozenset({32, 53})
# frozenset({32, 74})
# frozenset({53, 46})
# frozenset({109, 46})
# frozenset({109, 53})
# frozenset({65, 59})
# frozenset({36, 31})
# frozenset({46, 31})
# frozenset({80, 31})
# frozenset({36, 46})
# frozenset({80, 36})
# frozenset({80, 46})
# frozenset({61, 46})
# frozenset({26, 60})
# frozenset({28, 60})
# frozenset({74, 38})
# frozenset({74, 60})
# frozenset({66, 20})
# frozenset({73, 20})
# frozenset({73, 66})
# frozenset({32, 11})
# frozenset({11, 62})
# frozenset({32, 13})
# frozenset({32, 15})
# frozenset({49, 15})
# frozenset({62, 15})
# frozenset({32, 42})
# frozenset({32, 49})
# frozenset({32, 62})
# frozenset({32, 88})
# frozenset({42, 62})
# frozenset({62, 47})
# frozenset({49, 62})
# frozenset({88, 62})
# frozenset({11, 5})
# frozenset({5, 70})
# frozenset({73, 5})
# frozenset({70, 30})
# frozenset({73, 30})
# frozenset({73, 70})
# frozenset({49, 38})
# frozenset({42, 53})
# frozenset({44, 53})
# frozenset({44, 70})
# frozenset({53, 70})
# frozenset({20, 71})
# frozenset({11, 60})
# frozenset({11, 102})
# frozenset({17, 102})
# frozenset({18, 102})
# frozenset({27, 95})
# frozenset({42, 102})
# frozenset({46, 95})
# frozenset({102, 95})
# frozenset({11, 31})
# frozenset({66, 31})
# frozenset({75, 31})
# frozenset({66, 75})
# frozenset({41, 43})
# frozenset({65, 41})
# frozenset({20, 93})
# frozenset({93, 87})
# frozenset({75, 27})
# frozenset({58, 75})
# frozenset({75, 61})
# frozenset({0, 75})
# frozenset({102, 7})
# frozenset({8, 46})
# frozenset({8, 102})
# frozenset({102, 14})
# frozenset({67, 102})
# frozenset({80, 75})
# frozenset({75, 102})
# frozenset({80, 102})
# frozenset({27, 70})
# frozenset({35, 70})
# frozenset({65, 22})
# frozenset({65, 42})
# frozenset({65, 78})
# frozenset({2, 62})
# frozenset({62, 22})
# frozenset({102, 22})
# frozenset({27, 62})
# frozenset({62, 30})
# frozenset({46, 38})
# frozenset({62, 38})
# frozenset({102, 38})
# frozenset({62, 46})
# frozenset({52, 62})
# frozenset({52, 102})
# frozenset({58, 62})
# frozenset({102, 62})
# frozenset({50, 62})
# frozenset({59, 62})
# frozenset({59, 29})
# frozenset({29, 70})
# frozenset({42, 59})
# frozenset({59, 70})
# frozenset({0, 85})
# frozenset({27, 85})
# frozenset({32, 85})
# frozenset({80, 85})
# frozenset({49, 55})
# frozenset({59, 55})
# frozenset({66, 55})
# frozenset({66, 59})
# frozenset({5, 15})
# frozenset({65, 10})
# frozenset({65, 61})
# frozenset({4, 53})
# frozenset({74, 13})
# frozenset({53, 21})
# frozenset({109, 21})
# frozenset({33, 23})
# frozenset({74, 23})
# frozenset({109, 23})
# frozenset({25, 33})
# frozenset({33, 53})
# frozenset({33, 60})
# frozenset({33, 75})
# frozenset({75, 53})
# frozenset({60, 109})
# frozenset({74, 75})
# frozenset({75, 109})
# frozenset({17, 34})
# frozenset({36, 21})
# frozenset({34, 62})
# frozenset({36, 62})
# frozenset({10, 29})
# frozenset({68, 13})
# frozenset({27, 68})
# frozenset({29, 55})
# frozenset({68, 29})
# frozenset({29, 102})
# frozenset({68, 55})
# frozenset({102, 55})
# frozenset({68, 102})
# frozenset({50, 30})
# frozenset({0, 82})
# frozenset({10, 82})
# frozenset({58, 82})
# frozenset({82, 75})
# frozenset({75, 95})
# frozenset({82, 95})
# frozenset({24, 73})
# frozenset({73, 34})
# frozenset({73, 51})
# frozenset({20, 61})
# frozenset({20, 109})
# frozenset({50, 61})
# frozenset({109, 61})
# frozenset({40, 60})
# frozenset({67, 60})
# frozenset({50, 67})
# frozenset({50, 46})
# frozenset({26, 102})
# frozenset({66, 102})
# frozenset({65, 47})
# frozenset({41, 7})
# frozenset({24, 41})
# frozenset({41, 30})
# frozenset({80, 41})
# frozenset({9, 33})
# frozenset({33, 30})
# frozenset({33, 49})
# frozenset({102, 23})
# frozenset({34, 102})
# frozenset({93, 95})
# frozenset({28, 29})
# frozenset({65, 28})
# frozenset({28, 71})
# frozenset({29, 71})
# frozenset({46, 71})
# frozenset({65, 71})
# frozenset({24, 87})
# frozenset({59, 30})
# frozenset({80, 50})
# frozenset({0, 98})
# frozenset({40, 9})
# frozenset({40, 20})
# frozenset({40, 98})
# frozenset({20, 15})
# frozenset({60, 15})
# frozenset({43, 38})
# frozenset({43, 60})
# frozenset({73, 55})
# frozenset({1, 42})
# frozenset({1, 50})
# frozenset({50, 12})
# frozenset({28, 85})
# frozenset({34, 85})
# frozenset({24, 102})
# frozenset({28, 23})
# frozenset({75, 28})
# frozenset({26, 59})
# frozenset({65, 62})
# frozenset({88, 27})
# frozenset({30, 71})
# frozenset({58, 71})
# frozenset({61, 71})
# frozenset({88, 71})
# frozenset({32, 43})
# frozenset({32, 60})
# frozenset({32, 61})
# frozenset({43, 62})
# frozenset({60, 62})
# frozenset({40, 62})
# frozenset({25, 70})
# frozenset({70, 46})
# frozenset({109, 70})
# frozenset({40, 23})
# frozenset({40, 27})
# frozenset({59, 52})
# frozenset({53, 5})
# frozenset({8, 53})
# frozenset({8, 62})
# frozenset({53, 62})
# frozenset({44, 30})
# frozenset({44, 47})
# frozenset({21, 102})
# frozenset({66, 15})
# frozenset({66, 52})
# frozenset({5, 55})
# frozenset({75, 55})
# frozenset({32, 14})
# frozenset({73, 23})
# frozenset({78, 15})
# frozenset({24, 62})
# frozenset({78, 62})
# frozenset({73, 42})
# frozenset({29, 38})
# frozenset({29, 95})
# frozenset({32, 38})
# frozenset({32, 78})
# frozenset({32, 95})
# frozenset({50, 38})
# frozenset({88, 22})
# frozenset({27, 53})
# frozenset({17, 55})
# frozenset({30, 55})
# frozenset({4, 12})
# frozenset({12, 20})
# frozenset({40, 12})
# frozenset({36, 70})
# frozenset({58, 31})
# frozenset({33, 20})
# frozenset({48, 55})
# frozenset({73, 87})
# frozenset({9, 31})
# frozenset({12, 31})
# frozenset({12, 30})
# frozenset({17, 33})
# frozenset({40, 33})
# frozenset({98, 13})
# frozenset({32, 34})
# frozenset({8, 59})
# frozenset({95, 7})
# frozenset({26, 95})
# frozenset({1, 28})
# frozenset({33, 5})
# frozenset({30, 15})
# frozenset({33, 15})
# frozenset({46, 15})
# frozenset({26, 46})
# frozenset({28, 30})
# frozenset({33, 46})
# frozenset({22, 31})
# frozenset({74, 22})
# frozenset({74, 47})
# frozenset({1, 11})
# frozenset({74, 59})
# frozenset({62, 23})
# frozenset({27, 31})
# frozenset({28, 31})
# frozenset({33, 29})
# frozenset({29, 62})
# frozenset({33, 31})
# frozenset({62, 31})
# frozenset({68, 31})
# frozenset({33, 68})
# frozenset({36, 68})
# frozenset({68, 46})
# frozenset({68, 62})
# frozenset({80, 68})
# frozenset({20, 95})
# frozenset({24, 95})
# frozenset({60, 87})
# frozenset({95, 87})
# frozenset({5, 95})
# frozenset({59, 23})
# frozenset({70, 23})
# frozenset({95, 23})
# frozenset({59, 27})
# frozenset({59, 28})
# frozenset({28, 95})
# frozenset({88, 59})
# frozenset({59, 95})
# frozenset({62, 95})
# frozenset({88, 70})
# frozenset({70, 95})
# frozenset({88, 95})
# frozenset({1, 55})
# frozenset({35, 22})
# frozenset({9, 61})
# frozenset({61, 21})
# frozenset({5, 22})
# frozenset({22, 55})
# frozenset({70, 22})
# frozenset({51, 55})
# frozenset({88, 51})
# frozenset({70, 55})
# frozenset({88, 55})
# frozenset({74, 70})
# frozenset({88, 74})
# frozenset({17, 61})
# frozenset({42, 71})
# frozenset({52, 61})
# frozenset({73, 61})
# frozenset({73, 71})
# frozenset({0, 61})
# frozenset({17, 70})
# frozenset({60, 30})
# frozenset({65, 30})
# frozenset({46, 55})
# frozenset({59, 46})
# frozenset({59, 47})
# frozenset({60, 55})
# frozenset({65, 55})
# frozenset({11, 53})
# frozenset({8, 74})
# frozenset({2, 54})
# frozenset({28, 44})
# frozenset({61, 47})
# frozenset({65, 14})
# frozenset({98, 14})
# frozenset({65, 98})
# frozenset({58, 44})
# frozenset({40, 55})
# frozenset({51, 30})
# frozenset({4, 62})
# frozenset({82, 62})
# frozenset({102, 87})
# frozenset({40, 59})
# frozenset({59, 85})
# frozenset({65, 33})
# frozenset({87, 7})
# frozenset({21, 87})
# frozenset({26, 87})
# frozenset({8, 66})
# frozenset({8, 73})
# frozenset({9, 66})
# frozenset({27, 47})
# frozenset({68, 95})
# frozenset({58, 85})
# frozenset({85, 102})
# frozenset({98, 43})
# frozenset({98, 62})
# frozenset({61, 15})
# frozenset({109, 15})
# frozenset({28, 109})
# frozenset({109, 38})
# frozenset({43, 109})
# frozenset({52, 109})
# frozenset({44, 38})
# frozenset({44, 95})
# frozenset({48, 95})
# frozenset({65, 74})
# frozenset({12, 87})
# frozenset({98, 27})
# frozenset({53, 29})
# frozenset({98, 53})
# frozenset({8, 82})
# frozenset({82, 11})
# frozenset({54, 7})
# frozenset({9, 54})
# frozenset({54, 14})
# frozenset({21, 54})
# frozenset({26, 54})
# frozenset({33, 35})
# frozenset({1, 9})
# frozenset({98, 21})
# frozenset({26, 98})
# frozenset({42, 98})
# frozenset({58, 98})
# frozenset({98, 15})
# frozenset({98, 61})
# frozenset({27, 78})
# frozenset({27, 15})
# frozenset({50, 15})
# frozenset({40, 1})
# frozenset({1, 58})
# frozenset({1, 61})
# frozenset({17, 82})
# frozenset({80, 82})
# frozenset({66, 70})
# frozenset({5, 78})
# frozenset({80, 9})
# frozenset({44, 22})
# frozenset({98, 46})
# frozenset({49, 98})
# frozenset({73, 109})
# frozenset({61, 87})
# frozenset({75, 87})
# frozenset({40, 88})
# frozenset({59, 15})
# frozenset({1, 23})
# frozenset({1, 47})
# frozenset({74, 36})
# frozenset({55, 15})
# frozenset({93, 15})
# frozenset({93, 30})
# frozenset({32, 55})
# frozenset({32, 59})
# frozenset({32, 93})
# frozenset({93, 55})
# frozenset({59, 93})
# frozenset({40, 75})
# frozenset({75, 62})
# frozenset({85, 62})
# frozenset({75, 85})
# frozenset({43, 29})
# frozenset({66, 74})
# frozenset({80, 74})
# frozenset({74, 87})
# frozenset({42, 87})
# frozenset({98, 95})
# frozenset({61, 23})
# frozenset({34, 61})
# frozenset({34, 70})
# frozenset({34, 71})
# frozenset({34, 109})
# frozenset({70, 38})
# frozenset({38, 71})
# frozenset({43, 71})
# frozenset({61, 70})
# frozenset({70, 71})
# frozenset({109, 71})
# frozenset({73, 38})
# frozenset({80, 38})
# frozenset({41, 38})
# frozenset({41, 49})
# frozenset({49, 109})
# frozenset({102, 31})
# frozenset({33, 78})
# frozenset({33, 102})
# frozenset({102, 78})
# frozenset({68, 5})
# frozenset({9, 68})
# frozenset({24, 68})
# frozenset({67, 71})
# frozenset({80, 61})
# frozenset({54, 6})
# frozenset({98, 7})
# frozenset({98, 23})
# frozenset({62, 54})
# frozenset({98, 54})
# frozenset({34, 5})
# frozenset({34, 59})
# frozenset({34, 66})
# frozenset({73, 59})
# frozenset({59, 78})
# frozenset({66, 62})
# frozenset({73, 62})
# frozenset({88, 66})
# frozenset({88, 73})
# frozenset({13, 31})
# frozenset({59, 31})
# frozenset({54, 55})
# frozenset({68, 22})
# frozenset({93, 13})
# frozenset({40, 29})
# frozenset({93, 29})
# frozenset({33, 43})
# frozenset({33, 93})
# frozenset({40, 46})
# frozenset({40, 65})
# frozenset({40, 93})
# frozenset({93, 46})
# frozenset({58, 93})
# frozenset({65, 93})
# frozenset({65, 95})
# frozenset({67, 93})
# frozenset({11, 61})
# frozenset({59, 61})
# frozenset({41, 47})
# frozenset({65, 44})
# frozenset({85, 30})
# frozenset({12, 68})
# frozenset({66, 12})
# frozenset({66, 43})
# frozenset({73, 65})
# frozenset({10, 54})
# frozenset({12, 54})
# frozenset({54, 31})
# frozenset({36, 85})
# frozenset({50, 54})
# frozenset({50, 85})
# frozenset({12, 95})
# frozenset({20, 30})
# frozenset({20, 68})
# frozenset({68, 30})
# frozenset({28, 22})
# frozenset({26, 85})
# frozenset({59, 44})
# frozenset({44, 85})
# frozenset({85, 70})
# frozenset({82, 13})
# frozenset({49, 82})
# frozenset({36, 60})
# frozenset({36, 95})
# frozenset({73, 49})
# frozenset({73, 58})
# frozenset({75, 36})
# frozenset({109, 5})
# frozenset({27, 109})
# frozenset({109, 62})
# frozenset({68, 78})
# frozenset({68, 109})
# frozenset({109, 78})
# frozenset({70, 54})
# frozenset({80, 43})
# frozenset({11, 109})
# frozenset({12, 55})
# frozenset({12, 109})
# frozenset({109, 55})
# frozenset({28, 55})
# frozenset({32, 41})
# frozenset({32, 68})
# frozenset({32, 70})
# frozenset({32, 71})
# frozenset({41, 71})
# frozenset({42, 68})
# frozenset({68, 71})
# frozenset({68, 47})
# frozenset({5, 102})
# frozenset({65, 1})
# frozenset({1, 66})
# frozenset({65, 9})
# frozenset({65, 66})
# frozenset({50, 93})
# ...
# frozenset({9, 10, 18})
# frozenset({9, 18, 52})
# frozenset({9, 18, 58})
# frozenset({18, 52, 58})
# frozenset({25, 2, 22})
# frozenset({0, 4, 13})
# frozenset({0, 10, 4})
# frozenset({0, 10, 42})
# frozenset({10, 4, 13})
# frozenset({42, 4, 13})
# frozenset({17, 42, 58})
# frozenset({18, 27, 4})
# frozenset({48, 18, 27})
# frozenset({25, 20, 13})
# frozenset({25, 67, 20})
# frozenset({25, 26, 20})
# frozenset({2, 11, 58})
# frozenset({24, 18, 14})
# frozenset({24, 10, 4})
# frozenset({25, 26, 67})
# frozenset({67, 18, 26})
# frozenset({10, 42, 7})
# frozenset({10, 14, 7})
# frozenset({48, 0, 18})
# frozenset({48, 2, 13})
# frozenset({0, 48, 13})
# frozenset({34, 4, 6})
# frozenset({0, 17, 10})
# frozenset({17, 10, 26})
# frozenset({17, 10, 58})
# frozenset({0, 10, 30})
# frozenset({0, 17, 30})
# frozenset({17, 58, 30})
# frozenset({10, 26, 30})
# frozenset({10, 58, 30})
# frozenset({43, 67, 6})
# frozenset({62, 10, 6})
# frozenset({62, 21, 6})
# frozenset({26, 6, 7})
# frozenset({47, 6, 7})
# frozenset({2, 6, 47})
# frozenset({49, 4, 6})
# frozenset({4, 6, 47})
# frozenset({2, 26, 7})
# frozenset({49, 2, 26})
# frozenset({26, 58, 6})
# frozenset({49, 13, 7})
# frozenset({26, 13, 7})
# frozenset({4, 13, 7})
# frozenset({49, 6, 47})
# frozenset({49, 4, 7})
# frozenset({49, 26, 7})
# frozenset({49, 2, 13})
# frozenset({58, 4, 13})
# frozenset({49, 4, 13})
# frozenset({58, 6, 47})
# frozenset({26, 4, 7})
# frozenset({49, 58, 13})
# frozenset({58, 26, 7})
# frozenset({9, 11, 6})
# frozenset({42, 6, 23})
# frozenset({18, 42, 23})
# frozenset({9, 21, 6})
# frozenset({9, 6, 47})
# frozenset({21, 6, 47})
# frozenset({25, 11, 9})
# frozenset({25, 21, 9})
# frozenset({11, 6, 47})
# frozenset({43, 20, 13})
# frozenset({25, 43, 20})
# frozenset({49, 2, 20})
# frozenset({49, 10, 20})
# frozenset({49, 20, 13})
# frozenset({10, 11, 7})
# frozenset({10, 6, 14})
# frozenset({10, 4, 7})
# frozenset({10, 18, 4})
# frozenset({0, 18, 4})
# frozenset({0, 9, 18})
# frozenset({18, 11, 14})
# frozenset({11, 6, 14})
# frozenset({10, 42, 58})
# frozenset({2, 21, 30})
# frozenset({48, 2, 21})
# frozenset({48, 2, 30})
# frozenset({2, 52, 30})
# frozenset({48, 52, 30})
# frozenset({18, 42, 52})
# frozenset({25, 52, 6})
# frozenset({25, 18, 52})
# frozenset({2, 52, 50})
# frozenset({2, 11, 4})
# frozenset({11, 4, 13})
# frozenset({42, 43, 6})
# frozenset({50, 52, 6})
# frozenset({50, 43, 6})
# frozenset({25, 50, 42})
# frozenset({25, 50, 43})
# frozenset({25, 42, 43})
# frozenset({25, 18, 23})
# frozenset({25, 23, 49})
# frozenset({48, 43, 67})
# frozenset({67, 2, 26})
# frozenset({48, 13, 7})
# frozenset({4, 6, 52})
# frozenset({18, 4, 52})
# frozenset({5, 21, 6})
# frozenset({48, 10, 13})
# frozenset({9, 4, 6})
# frozenset({9, 34, 6})
# frozenset({9, 2, 4})
# frozenset({2, 42, 21})
# frozenset({9, 2, 21})
# frozenset({42, 4, 6})
# frozenset({42, 21, 6})
# frozenset({25, 42, 21})
# frozenset({42, 34, 6})
# frozenset({25, 42, 4})
# frozenset({9, 2, 42})
# frozenset({2, 13, 21})
# frozenset({17, 2, 21})
# frozenset({25, 13, 21})
# frozenset({25, 21, 17})
# frozenset({21, 13, 7})
# frozenset({17, 21, 7})
# frozenset({24, 21, 7})
# frozenset({25, 67, 11})
# frozenset({11, 18, 67})
# frozenset({49, 11, 6})
# frozenset({17, 11, 49})
# frozenset({49, 2, 11})
# frozenset({9, 6, 23})
# frozenset({58, 6, 23})
# frozenset({25, 58, 11})
# frozenset({58, 11, 6})
# frozenset({25, 26, 7})
# frozenset({26, 67, 6})
# frozenset({26, 14, 7})
# frozenset({25, 43, 7})
# frozenset({26, 67, 7})
# frozenset({25, 67, 43})
# frozenset({48, 26, 7})
# frozenset({25, 10, 42})
# frozenset({48, 10, 42})
# frozenset({48, 25, 52})
# frozenset({48, 25, 42})
# frozenset({48, 10, 52})
# frozenset({24, 21, 6})
# frozenset({17, 10, 67})
# frozenset({10, 18, 30})
# frozenset({49, 10, 18})
# frozenset({17, 18, 21})
# frozenset({18, 52, 30})
# frozenset({18, 21, 30})
# frozenset({49, 18, 67})
# frozenset({49, 18, 52})
# frozenset({17, 67, 49})
# frozenset({24, 25, 50})
# frozenset({24, 50, 6})
# frozenset({24, 17, 30})
# frozenset({18, 4, 50})
# frozenset({2, 20, 6})
# frozenset({10, 13, 6})
# frozenset({10, 67, 6})
# frozenset({24, 10, 6})
# frozenset({24, 25, 10})
# frozenset({25, 26, 10})
# frozenset({26, 10, 13})
# frozenset({25, 10, 67})
# frozenset({10, 20, 6})
# frozenset({10, 6, 47})
# frozenset({47, 6, 23})
# frozenset({11, 6, 23})
# frozenset({26, 11, 6})
# frozenset({18, 11, 23})
# frozenset({11, 18, 26})
# frozenset({18, 42, 14})
# frozenset({48, 6, 47})
# frozenset({67, 6, 47})
# frozenset({25, 11, 43})
# frozenset({11, 18, 43})
# frozenset({49, 10, 6})
# frozenset({49, 67, 6})
# frozenset({48, 9, 7})
# frozenset({48, 10, 7})
# frozenset({10, 18, 50})
# frozenset({9, 2, 18})
# frozenset({18, 50, 52})
# frozenset({25, 10, 50})
# frozenset({25, 10, 9})
# frozenset({48, 25, 9})
# frozenset({9, 2, 52})
# frozenset({48, 2, 10})
# frozenset({48, 9, 2})
# frozenset({48, 2, 50})
# frozenset({0, 5, 6})
# frozenset({4, 5, 6})
# frozenset({48, 13, 6})
# frozenset({2, 52, 13})
# frozenset({52, 13, 6})
# frozenset({0, 24, 48})
# frozenset({49, 42, 13})
# frozenset({49, 11, 13})
# frozenset({0, 26, 6})
# frozenset({0, 17, 67})
# frozenset({17, 58, 67})
# frozenset({24, 17, 58})
# frozenset({48, 26, 6})
# frozenset({26, 52, 6})
# frozenset({42, 43, 13})
# frozenset({43, 11, 13})
# frozenset({2, 27, 6})
# frozenset({25, 11, 20})
# frozenset({9, 43, 6})
# frozenset({25, 50, 11})
# frozenset({25, 11, 23})
# frozenset({43, 11, 6})
# frozenset({25, 50, 23})
# frozenset({9, 25, 23})
# frozenset({25, 43, 23})
# frozenset({24, 18, 30})
# frozenset({50, 58, 13})
# frozenset({25, 10, 11})
# frozenset({25, 11, 14})
# frozenset({25, 11, 22})
# frozenset({25, 10, 14})
# frozenset({25, 10, 22})
# frozenset({25, 21, 22})
# frozenset({25, 20, 21})
# frozenset({25, 20, 14})
# frozenset({25, 20, 22})
# frozenset({48, 25, 23})
# frozenset({42, 67, 7})
# frozenset({25, 42, 67})
# frozenset({25, 58, 67})
# frozenset({42, 58, 7})
# frozenset({25, 42, 58})
# frozenset({42, 67, 58})
# frozenset({50, 20, 13})
# frozenset({50, 43, 13})
# frozenset({24, 50, 13})
# frozenset({9, 50, 13})
# frozenset({9, 20, 13})
# frozenset({24, 43, 13})
# frozenset({9, 43, 13})
# frozenset({24, 9, 13})
# frozenset({0, 6, 47})
# frozenset({24, 6, 47})
# frozenset({10, 26, 7})
# frozenset({48, 10, 26})
# frozenset({18, 4, 58})
# frozenset({11, 67, 6})
# frozenset({43, 4, 13})
# frozenset({25, 26, 4})
# frozenset({26, 34, 6})
# frozenset({17, 43, 13})
# frozenset({17, 18, 58})
# frozenset({17, 5, 6})
# frozenset({58, 5, 6})
# frozenset({17, 58, 25})
# frozenset({18, 67, 58})
# frozenset({24, 25, 43})
# frozenset({67, 18, 27})
# frozenset({24, 18, 27})
# frozenset({10, 5, 6})
# frozenset({42, 5, 6})
# frozenset({42, 27, 6})
# frozenset({27, 5, 6})
# frozenset({49, 18, 42})
# frozenset({9, 18, 42})
# frozenset({18, 27, 42})
# frozenset({49, 18, 13})
# frozenset({9, 18, 13})
# frozenset({48, 17, 49})
# frozenset({17, 13, 49})
# frozenset({17, 42, 49})
# frozenset({48, 42, 13})
# frozenset({9, 42, 13})
# frozenset({17, 13, 9})
# frozenset({49, 13, 9})
# frozenset({48, 9, 13})
# frozenset({24, 4, 7})
# frozenset({24, 58, 7})
# frozenset({5, 6, 23})
# frozenset({49, 5, 6})
# frozenset({50, 5, 6})
# frozenset({24, 18, 50})
# frozenset({0, 6, 23})
# frozenset({18, 58, 23})
# frozenset({18, 26, 7})
# frozenset({18, 42, 58})
# frozenset({0, 26, 7})
# frozenset({24, 18, 58})
# frozenset({24, 26, 7})
# frozenset({0, 42, 67})
# frozenset({0, 42, 58})
# frozenset({42, 26, 7})
# frozenset({24, 42, 67})
# frozenset({17, 18, 43})
# frozenset({18, 43, 4})
# frozenset({48, 43, 7})
# frozenset({17, 43, 25})
# frozenset({9, 18, 43})
# frozenset({48, 17, 43})
# frozenset({48, 25, 43})
# frozenset({25, 10, 4})
# frozenset({25, 50, 4})
# frozenset({10, 30, 7})
# frozenset({48, 42, 7})
# frozenset({42, 30, 7})
# frozenset({48, 10, 30})
# frozenset({48, 42, 30})
# frozenset({25, 10, 20})
# frozenset({10, 26, 20})
# frozenset({25, 42, 49})
# frozenset({48, 49, 2})
# frozenset({49, 67, 7})
# frozenset({49, 42, 7})
# frozenset({26, 11, 13})
# frozenset({11, 67, 7})
# frozenset({11, 21, 7})
# frozenset({26, 11, 7})
# frozenset({42, 21, 7})
# frozenset({26, 21, 7})
# frozenset({11, 14, 7})
# frozenset({11, 30, 7})
# frozenset({0, 49, 6})
# frozenset({18, 43, 42})
# frozenset({11, 18, 27})
# frozenset({49, 10, 7})
# frozenset({9, 49, 7})
# frozenset({9, 21, 7})
# frozenset({10, 21, 7})
# frozenset({10, 42, 20})
# frozenset({49, 10, 42})
# frozenset({42, 4, 7})
# frozenset({4, 21, 7})
# frozenset({10, 4, 20})
# frozenset({49, 10, 4})
# frozenset({58, 30, 7})
# frozenset({0, 25, 58})
# frozenset({2, 58, 30})
# frozenset({48, 13, 30})
# frozenset({17, 58, 13})
# frozenset({58, 13, 30})
# frozenset({48, 58, 13})
# frozenset({62, 50, 6})
# frozenset({18, 4, 42})
# frozenset({0, 27, 6})
# frozenset({25, 21, 23})
# frozenset({25, 4, 13})
# frozenset({25, 13, 23})
# frozenset({25, 4, 23})
# frozenset({42, 20, 13})
# frozenset({9, 11, 13})
# frozenset({17, 18, 34})
# frozenset({18, 27, 7})
# frozenset({9, 18, 21})
# frozenset({9, 18, 34})
# frozenset({18, 27, 21})
# frozenset({18, 27, 34})
# frozenset({0, 21, 7})
# frozenset({0, 18, 21})
# frozenset({0, 18, 34})
# frozenset({25, 58, 4})
# frozenset({48, 25, 58})
# frozenset({48, 42, 58})
# frozenset({25, 10, 49})
# frozenset({18, 26, 50})
# frozenset({18, 50, 30})
# frozenset({17, 50, 13})
# frozenset({50, 13, 30})
# frozenset({10, 4, 58})
# frozenset({0, 25, 22})
# frozenset({24, 25, 20})
# frozenset({25, 18, 20})
# frozenset({18, 20, 13})
# frozenset({25, 50, 20})
# frozenset({25, 42, 20})
# frozenset({50, 6, 14})
# frozenset({50, 67, 6})
# frozenset({18, 67, 50})
# frozenset({9, 26, 13})
# frozenset({11, 2, 26})
# frozenset({17, 2, 26})
# frozenset({24, 25, 30})
# frozenset({0, 25, 26})
# frozenset({0, 26, 13})
# frozenset({26, 30, 7})
# frozenset({0, 13, 30})
# frozenset({0, 58, 13})
# frozenset({9, 30, 7})
# frozenset({9, 67, 7})
# frozenset({9, 58, 7})
# frozenset({9, 18, 30})
# frozenset({18, 58, 30})
# frozenset({25, 30, 49})
# frozenset({25, 67, 49})
# frozenset({25, 67, 9})
# frozenset({25, 9, 49})
# frozenset({25, 58, 9})
# frozenset({27, 10, 18})
# frozenset({27, 2, 18})
# frozenset({18, 27, 23})
# frozenset({10, 18, 20})
# frozenset({0, 25, 10})
# frozenset({0, 25, 20})
# frozenset({9, 20, 25})
# frozenset({17, 10, 20})
# frozenset({49, 17, 7})
# frozenset({49, 18, 43})
# frozenset({17, 25, 49})
# frozenset({17, 20, 25})
# frozenset({25, 10, 43})
# frozenset({25, 20, 7})
# frozenset({25, 43, 49})
# frozenset({25, 20, 49})
# frozenset({17, 20, 13})
# frozenset({49, 43, 13})
# frozenset({24, 10, 30})
# frozenset({18, 27, 52})
# frozenset({0, 2, 26})
# frozenset({0, 49, 2})
# frozenset({24, 9, 6})
# frozenset({13, 21, 6})
# frozenset({20, 13, 6})
# frozenset({62, 17, 6})
# frozenset({62, 52, 6})
# frozenset({4, 13, 30})
# frozenset({18, 27, 58})
# frozenset({10, 13, 30})
# frozenset({2, 18, 20})
# frozenset({25, 2, 20})
# frozenset({18, 50, 34})
# frozenset({9, 2, 13})
# frozenset({9, 2, 20})
# frozenset({2, 20, 50})
# frozenset({18, 34, 13})
# frozenset({48, 10, 43})
# frozenset({42, 58, 13})
# frozenset({58, 43, 13})
# frozenset({62, 67, 6})
# frozenset({18, 21, 13})
# frozenset({9, 67, 6})
# frozenset({58, 27, 6})
# frozenset({67, 27, 6})
# frozenset({25, 10, 23})
# frozenset({0, 25, 23})
# frozenset({25, 58, 23})
# frozenset({25, 11, 4})
# frozenset({25, 11, 30})
# frozenset({11, 4, 7})
# frozenset({17, 11, 30})
# frozenset({10, 67, 7})
# frozenset({25, 10, 30})
# frozenset({48, 10, 67})
# frozenset({24, 58, 13})
# frozenset({24, 10, 58})
# frozenset({48, 67, 13})
# frozenset({48, 2, 43})
# frozenset({48, 43, 13})
# frozenset({25, 26, 17})
# frozenset({25, 26, 58})
# frozenset({0, 49, 7})
# frozenset({17, 4, 13})
# frozenset({0, 17, 49})
# frozenset({17, 58, 49})
# frozenset({17, 26, 7})
# frozenset({0, 49, 13})
# frozenset({0, 25, 49})
# frozenset({24, 18, 21})
# frozenset({62, 2, 6})
# frozenset({62, 24, 6})
# frozenset({24, 9, 7})
# frozenset({25, 10, 21})
# frozenset({18, 4, 21})
# frozenset({2, 20, 58})
# frozenset({2, 11, 20})
# frozenset({18, 11, 58})
# frozenset({58, 20, 13})
# frozenset({10, 20, 58})
# frozenset({9, 26, 6})
# frozenset({9, 6, 30})
# frozenset({52, 6, 30})
# frozenset({9, 18, 26})
# frozenset({27, 52, 6})
# frozenset({26, 50, 6})
# frozenset({49, 10, 26})
# frozenset({24, 42, 30})
# frozenset({9, 26, 7})
# frozenset({25, 26, 42})
# frozenset({25, 26, 9})
# frozenset({48, 0, 30})
# frozenset({25, 20, 6})
# frozenset({25, 58, 20})
# frozenset({13, 6, 23})
# frozenset({62, 6, 23})
# frozenset({62, 49, 6})
# frozenset({62, 5, 6})
# frozenset({11, 5, 6})
# frozenset({62, 27, 6})
# frozenset({11, 27, 6})
# frozenset({62, 11, 6})
# frozenset({24, 2, 30})
# frozenset({25, 58, 22})
# frozenset({10, 6, 30})
# frozenset({48, 10, 58})
# frozenset({10, 26, 42})
# frozenset({24, 25, 49})
# frozenset({24, 25, 9})
# frozenset({9, 18, 23})
# frozenset({24, 9, 2})
# frozenset({24, 9, 18})
# frozenset({49, 2, 9})
# frozenset({10, 50, 13})
# frozenset({48, 25, 21})
# frozenset({17, 2, 67})
# frozenset({21, 6, 30})
# frozenset({48, 18, 11})
# frozenset({48, 2, 11})
# frozenset({0, 10, 48})
# frozenset({50, 6, 30})
# frozenset({27, 6, 7})
# frozenset({27, 4, 6})
# frozenset({27, 6, 47})
# frozenset({48, 24, 7})
# frozenset({48, 24, 67})
# frozenset({47, 6, 14})
# frozenset({18, 43, 50})
# frozenset({24, 25, 4})
# frozenset({24, 27, 6})
# frozenset({25, 21, 30})
# frozenset({21, 30, 7})
# frozenset({2, 11, 30})
# frozenset({11, 6, 30})
# frozenset({48, 10, 4})
# frozenset({9, 2, 26})
# frozenset({9, 2, 30})
# frozenset({18, 26, 34})
# frozenset({18, 34, 30})
# frozenset({25, 42, 30})
# frozenset({10, 18, 14})
# frozenset({9, 18, 14})
# frozenset({50, 58, 6})
# frozenset({0, 25, 50})
# frozenset({25, 50, 58})
# frozenset({26, 5, 6})
# frozenset({0, 18, 30})
# frozenset({43, 6, 47})
# frozenset({25, 26, 23})
# frozenset({25, 42, 23})
# frozenset({9, 11, 7})
# frozenset({18, 11, 30})
# frozenset({0, 49, 18})
# frozenset({49, 18, 11})
# frozenset({9, 18, 11})
# frozenset({11, 13, 30})
# frozenset({9, 2, 11})
# frozenset({9, 13, 30})
# frozenset({62, 6, 30})
# frozenset({48, 24, 30})
# frozenset({48, 24, 10})
# frozenset({48, 10, 20})
# frozenset({18, 52, 14})
# frozenset({48, 11, 7})
# frozenset({18, 11, 4})
# frozenset({49, 2, 50})
# frozenset({49, 43, 6})
# frozenset({43, 5, 6})
# frozenset({24, 25, 58})
# frozenset({24, 2, 50})
# frozenset({24, 10, 42})
# frozenset({2, 20, 42})
# frozenset({13, 14, 7})
# frozenset({34, 5, 6})
# frozenset({62, 4, 6})
# frozenset({18, 4, 34})
# frozenset({62, 34, 6})
# frozenset({17, 67, 13})
# frozenset({49, 6, 30})
# frozenset({24, 6, 30})
# frozenset({18, 13, 23})
# frozenset({25, 30, 23})
# frozenset({25, 20, 30})
# frozenset({20, 13, 30})
# frozenset({25, 20, 23})
# frozenset({62, 42, 6})
# frozenset({24, 49, 10})
# frozenset({58, 11, 13})
# frozenset({48, 11, 13})
# frozenset({48, 49, 10})
# frozenset({49, 10, 58})
# frozenset({2, 26, 20})
# frozenset({10, 2, 26})
# frozenset({52, 6, 47})
# frozenset({25, 43, 21})
# frozenset({62, 43, 6})
# frozenset({34, 27, 6})
# frozenset({34, 6, 47})
# frozenset({48, 42, 43})
# frozenset({11, 4, 6})
# frozenset({48, 20, 13})
# frozenset({20, 4, 13})
# frozenset({0, 49, 10})
# frozenset({62, 6, 47})
# frozenset({25, 4, 22})
# frozenset({49, 18, 4})
# frozenset({11, 17, 67})
# frozenset({11, 2, 67})
# frozenset({26, 20, 13})
# frozenset({18, 50, 58})
# frozenset({10, 26, 4})
# frozenset({48, 0, 43})
# frozenset({2, 20, 30})
# frozenset({10, 20, 30})
# frozenset({34, 6, 30})
# frozenset({25, 50, 30})
# frozenset({25, 50, 67})
# frozenset({43, 4, 6})
# frozenset({9, 4, 13})
# frozenset({24, 48, 13})
# frozenset({24, 42, 48})
# frozenset({17, 10, 11})
# frozenset({48, 43, 30})
# frozenset({48, 17, 11})
# frozenset({17, 58, 11})
# frozenset({10, 67, 42})
# frozenset({26, 21, 6})
# frozenset({2, 26, 50})
# frozenset({25, 4, 20})
# frozenset({17, 34, 6})
# frozenset({18, 11, 34})
# frozenset({2, 50, 30})
# frozenset({50, 4, 13})
# frozenset({2, 67, 50})
# frozenset({49, 2, 67})
# frozenset({25, 43, 22})
# frozenset({2, 26, 21})
# frozenset({25, 30, 22})
# frozenset({48, 25, 20})
# frozenset({62, 58, 6})
# frozenset({5, 6, 47})
# frozenset({2, 20, 21})
# frozenset({58, 11, 7})
# frozenset({9, 2, 67})
# frozenset({17, 2, 20})
# frozenset({2, 67, 20})
# frozenset({48, 18, 6, 7})
# frozenset({17, 18, 6, 7})
# frozenset({18, 6, 7, 25})
# frozenset({18, 67, 6, 7})
# frozenset({48, 6, 7, 25})
# frozenset({48, 17, 6, 7})
# frozenset({48, 17, 18, 6})
# frozenset({48, 18, 6, 25})
# frozenset({48, 18, 67, 6})
# frozenset({17, 18, 6, 25})
# frozenset({17, 18, 67, 6})
# frozenset({17, 6, 7, 25})
# frozenset({18, 67, 6, 25})
# frozenset({2, 18, 67, 6})
# frozenset({48, 2, 18, 6})
# frozenset({18, 6, 25, 13})
# frozenset({2, 6, 7, 25})
# frozenset({2, 18, 6, 42})
# frozenset({2, 18, 6, 7})
# frozenset({2, 18, 6, 25})
# frozenset({17, 2, 18, 6})
# frozenset({2, 18, 6, 13})
# frozenset({18, 6, 7, 42})
# frozenset({17, 18, 6, 42})
# frozenset({18, 6, 25, 42})
# frozenset({18, 6, 42, 13})
# frozenset({18, 6, 7, 13})
# frozenset({17, 18, 6, 13})
# frozenset({17, 2, 6, 7})
# frozenset({18, 2, 7, 25})
# frozenset({18, 67, 6, 13})
# frozenset({48, 2, 6, 25})
# frozenset({48, 2, 6, 7})
# frozenset({48, 18, 6, 42})
# frozenset({18, 67, 6, 42})
# frozenset({48, 18, 6, 13})

# %%
freq_items[1:(len(freq_items) - 1)][1]
# Out:
# [frozenset({2, 6, 18}),
#  frozenset({6, 18, 42}),
#  frozenset({6, 7, 18}),
#  frozenset({6, 7, 48}),
#  frozenset({6, 18, 48}),
#  frozenset({2, 6, 25}),
#  frozenset({6, 17, 18}),
#  frozenset({6, 7, 25}),
#  frozenset({6, 7, 17}),
#  frozenset({6, 18, 25}),
#  frozenset({6, 18, 67}),
#  frozenset({7, 18, 25}),
#  frozenset({6, 25, 48}),
#  frozenset({2, 18, 25}),
#  frozenset({2, 6, 48}),
#  frozenset({2, 6, 7}),
#  frozenset({6, 13, 18})]

# %%
len(freq_items)
# Out:
# 4
